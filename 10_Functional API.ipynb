# %% [markdown]
# # __Call__ magic method
# - 객체를 함수처럼 호출 할 수 있도록 한다.
# - `객체()` 로 호출 할 때 __call__ 메소드가 호출되어 실행된다.

# %%
class Person: 
  def __init__(self, name):
    self.name = name

  def __call__(self, age):
    print(f'이름: {self.name}, 나이: {age}') #age : 매가변수로 받은 값. name: 객체의 attribute
    return f'이름: {self.name}, 나이: {age} - 문자열' #return value

# %%
p = Person("홍길동")
print(p.name)
r = p(20)
# Out:
# 홍길동
# 이름: 홍길동, 나이: 20

# %%
print(r)
# Out:
# 이름: 홍길동, 나이: 20 - 문자열

# %%
r = Person("홍길동")(20) #객체 생성하면서 __call__() 바로 홏출
print(r)
# Out:
# 이름: 홍길동, 나이: 20
# 이름: 홍길동, 나이: 20 - 문자열

# %% [markdown]
# # Functional API
# - Sequential 모델은 각 Layer들의 입력과 출력이 하나라고 가정한다. 그리고 각각의 Layer(입력층, 은닉층, 출력층)들을 차례대로 쌓아 구성한다. 그래서 다양한 구조의 네트워크를 만드는데 한계가 있다.
# - 함수형 API를 사용하면 **다중입력, 다중출력, 그래프 형태**의 다양한 형태의 레이어들을 유연하게 구성할 수 있다.
#
# - Functional API는 직접 텐서들의 입출력을 다룬다.
# - 함수호출 처럼 Layer를 이용하여 입력 텐서(Input Tensor)를 입력 받고 그 결과를 출력 텐서(Output Tensor)로 반환하는 형식으로 모델을 구현한다.
#
# ```python
# input_tensor = Input(shape=(16,))
# dense = layers.Dense(32, activation='relu')(input_tensor)
# output_tensor = layers.Dense(32, activation='sigmoid')(dense)
#
# model = models.Model(input_tensor, output_tensor)
# ```

# %% [markdown]
# ## Sequential, Functional API

# %% [markdown]
# ### Sequential

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import applications
from tensorflow.keras import layers, models

# %%
seq_model = keras.Sequential()
seq_model.add(layers.Input(shape=(32,32,3)))

seq_model.add(layers.Conv2D(filters=64, kernel_size=3, padding='same', activation='relu'))
seq_model.add(layers.MaxPooling2D(padding="same"))
seq_model.add(layers.Flatten())

seq_model.add(layers.Dense(units=256, activation='relu'))
seq_model.add(layers.Dense(units=10, activation='softmax', name='output_layer'))
seq_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 64)        1792
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 64)       0
#  )
#
#  flatten (Flatten)           (None, 16384)             0
#
#  dense (Dense)               (None, 256)               4194560
#
#  output_layer (Dense)        (None, 10)                2570
#
# =================================================================
# Total params: 4,198,922
# Trainable params: 4,198,922
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Functional API

# %%
# 레이어의 흐름 구조를 구현
input_tensor = layers.Input(shape=(32,32,3)) # 입력 값을 생성(레이어가 아님)

# y = f(input_tensor) # unit/layet/model 모두 함수
conv_tensor = layers.Conv2D(filters=64, kernel_size=3, padding='same', activation='relu')(input_tensor)
pool_tensor = layers.MaxPooling2D(padding='same')(conv_tensor)
flatten_tensor = layers.Flatten()(pool_tensor)
dense_tensor = layers.Dense(256, activation='relu')(flatten_tensor)
output_tensor = layers.Dense(10, activation='softmax')(dense_tensor)

# 모델 생성 -> input들과 output들을 넣어서 생성. 
#   => input들/output들 : 학습/추론할 때 실제 생성될 입력값, 출력값을 표현하는 tensor객체. 여러개일 경우 리스트로 묶어서 전달.
fn_model = models.Model(input_tensor, output_tensor)

# %%
fn_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 64)        1792
#
#  max_pooling2d_1 (MaxPooling  (None, 16, 16, 64)       0
#  2D)
#
#  flatten_1 (Flatten)         (None, 16384)             0
#
#  dense_1 (Dense)             (None, 256)               4194560
#
#  dense_2 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 4,198,922
# Trainable params: 4,198,922
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ##### 각 Layer의 출력 변수들 통일.
# - 일반적으로 block 단위로 동일한 변수명을 사용.
# - hidden layer들의 출력결과는 모두 동일한 변수명을 사용.

# %%
input_tensor = layers.Input(shape=(32,32,3))

x1 = layers.Conv2D(filters=16, kernel_size=3, padding='same', activation='relu')(input_tensor)
x1 = layers.MaxPooling2D(padding='same')(x1)

x2 = layers.Conv2D(filters=16, kernel_size=3, padding='same', activation='relu')(x1)
x2 = layers.MaxPooling2D(padding='same')(x2)

x3 = layers.Conv2D(filters=16, kernel_size=3, padding='same', activation='relu')(x2)
x3 = layers.Conv2D(filters=16, kernel_size=3, padding='same', activation='relu')(x3)
x3 = layers.MaxPooling2D(padding='same')(x3)

x4 = layers.Flatten()(x3)
output_tensor = layers.Dense(10, activation='softmax')(x4)

model3 = models.Model(input_tensor, output_tensor)

model3.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 16)        448
#
#  max_pooling2d_2 (MaxPooling  (None, 16, 16, 16)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 16)        2320
#
#  max_pooling2d_3 (MaxPooling  (None, 8, 8, 16)         0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 16)          2320
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 16)          2320
#
#  max_pooling2d_4 (MaxPooling  (None, 4, 4, 16)         0
#  2D)
#
#  flatten_2 (Flatten)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 9,978
# Trainable params: 9,978
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ##### trainable 설정

# %%
input_tensor = layers.Input(shape=(32,32,3))

c1 = layers.Conv2D(filters=16, kernel_size=3, padding='same', activation='relu')
c1.trainable = False
x1 = c1(input_tensor)

x1 = layers.MaxPooling2D(padding='same')(x1)

x2 = layers.Conv2D(filters=16, kernel_size=3, padding='same', activation='relu')(x1)
x2 = layers.MaxPooling2D(padding='same')(x2)

x3 = layers.Conv2D(filters=16, kernel_size=3, padding='same', activation='relu')(x2)
x3 = layers.Conv2D(filters=16, kernel_size=3, padding='same', activation='relu')(x3)
x3 = layers.MaxPooling2D(padding='same')(x3)

x4 = layers.Flatten()(x3)
output_tensor = layers.Dense(10, activation='softmax')(x4)

model3 = models.Model(input_tensor, output_tensor)

model3.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  conv2d_6 (Conv2D)           (None, 32, 32, 16)        448
#
#  max_pooling2d_5 (MaxPooling  (None, 16, 16, 16)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 16, 16, 16)        2320
#
#  max_pooling2d_6 (MaxPooling  (None, 8, 8, 16)         0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 8, 8, 16)          2320
#
#  conv2d_9 (Conv2D)           (None, 8, 8, 16)          2320
#
#  max_pooling2d_7 (MaxPooling  (None, 4, 4, 16)         0
#  2D)
#
#  flatten_3 (Flatten)         (None, 256)               0
#
#  dense_4 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 9,978
# Trainable params: 9,530
# Non-trainable params: 448
# _________________________________________________________________

# %% [markdown]
# ##### Transfer learning

# %%
backbone = applications.VGG16(include_top=False)
backbone.trainable = False

input_tensor = layers.Input(shape=(224,224,3))
x = backbone(input_tensor)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0.3)(x)
x = layers.Dense(512, activation='relu')(x)
output_tensor = layers.Dense(1, activation='sigmoid')(x)
output_tensor2 = layers.Dense(1, activation='sigmoid')(x)

model4 = models.Model(input_tensor, [output_tensor,output_tensor2])
model4.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_6 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  vgg16 (Functional)             (None, None, None,   14714688    ['input_6[0][0]']
#                                 512)
#
#  global_average_pooling2d (Glob  (None, 512)         0           ['vgg16[0][0]']
#  alAveragePooling2D)
#
#  dropout (Dropout)              (None, 512)          0           ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dense_5 (Dense)                (None, 512)          262656      ['dropout[0][0]']
#
#  dense_6 (Dense)                (None, 1)            513         ['dense_5[0][0]']
#
#  dense_7 (Dense)                (None, 1)            513         ['dense_5[0][0]']
#
# ==================================================================================================
# Total params: 14,978,370
# Trainable params: 263,682
# Non-trainable params: 14,714,688
# __________________________________________________________________________________________________

# %%
keras.utils.plot_model(model4, show_shapes=True)

# %% [markdown]
# ## 여러개의 출력결과를  합치는 Layer
#
# - 앞 레이어들에서 출력된 값이 여러개이고 이것을 하나의 Layer의 입력으로 넣어 줄 경우 **여러개의 출력값을 합쳐 줘야 한다.** 이때 단순이 합치거나 element wise 연산을 통해 합칠 수 있다.
# - 함수와 Layer class 두가지 방식을 제공한다.
#     - tensorflow.keras.layers 모듈로 제공
# - **concatenate(list, axis=-1)/Concatenate(axis=-1)([list])**
#     - 레이어들을 단순히 합친다. (붙이는 처리)
#     - list: 합칠 레이어들을 리스트에 묶어 전달
#     - axis: 합칠 기준축. (기본값: -1 : 마지막 축기준)
# - **add(list)/Add()(list), substract(list)/Subtract()(list), multiply(list)/Multiply()(list)**
#     - 같은 index의 값들을 계산해서(더하기, 빼기, 곱하기) 하나의 레이어로 만든다.
#     - list: 합칠 레이어들을 리스트에 묶어 전달

# %%
#ResNet의 Residual Block을 구현.
input_tensor = layers.Input(shape=(32,32,3))
x = layers.Conv2D(filters=64, kernel_size=7, padding='same', activation='relu')(input_tensor)
x = layers.MaxPooling2D(padding='same')(x)

# residual block : x-input
x1 = layers.Conv2D(filters=64, kernel_size=3, padding='same')(x)
x1 = layers.BatchNormalization()(x1)
x1 = layers.ReLU()(x1)
x1 = layers.Conv2D(filters=128, kernel_size=3, padding='same')(x1)
x1 = layers.BatchNormalization()(x1)
# point wise conv을 이용해 channel size 조정.
x1 = layers.Conv2D(filters=64, kernel_size=1, padding='same')(x1)  
#x와 x1을 더하기
x1 = layers.Add()([x, x1])   # x1 = layers.add([x, x1])

output_tensor = layers.ReLU()(x1)

rb_model = models.Model(input_tensor, output_tensor)

# %%
rb_model.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_7 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  conv2d_10 (Conv2D)             (None, 32, 32, 64)   9472        ['input_7[0][0]']
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 16, 16, 64)  0           ['conv2d_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 16, 16, 64)   36928       ['max_pooling2d_8[0][0]']
#
#  batch_normalization (BatchNorm  (None, 16, 16, 64)  256         ['conv2d_11[0][0]']
#  alization)
#
#  re_lu (ReLU)                   (None, 16, 16, 64)   0           ['batch_normalization[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 16, 16, 128)  73856       ['re_lu[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 16, 16, 128)  512        ['conv2d_12[0][0]']
#  rmalization)
#
#  conv2d_13 (Conv2D)             (None, 16, 16, 64)   8256        ['batch_normalization_1[0][0]']
#
#  add (Add)                      (None, 16, 16, 64)   0           ['max_pooling2d_8[0][0]',
#                                                                   'conv2d_13[0][0]']
#
#  re_lu_1 (ReLU)                 (None, 16, 16, 64)   0           ['add[0][0]']
#
# ==================================================================================================
# Total params: 129,280
# Trainable params: 128,896
# Non-trainable params: 384
# __________________________________________________________________________________________________

# %%
keras.utils.plot_model(rb_model, show_shapes=True)

# %% [markdown]
# ### 다중 출력 모델
# - 가정
#     - iris 데이터셋에서 꽃받침의 너비와 높이로 꽃잎의 너비, 높이, 꽃 종류를 예측하는 모델
#     - 출력결과가 3개가 나와야 한다.
# - X: 꽃받침 너비, 높이
# - y: 꽃잎 너비, 높이, 꽃 종류

# %%
from sklearn.datasets import load_iris

X, y = load_iris(return_X_y=True)
X.shape
# Out:
# (150, 4)

# %%
# X, y의 형태를 변환 
# y1: petal length, y2: petal width, y3: target
y1 = X[:, 2]
y2 = X[:, 3]
y3 = y

# X: sepal length, width
X = X[:, [0, 1]]
X.shape, y1.shape, y2.shape, y3.shape
# Out:
# ((150, 2), (150,), (150,), (150,))

# %% [markdown]
# ##### 모델 정의 및 컴파일

# %%
# 모델정의 - 입력: X, 출력: y1, y2, y3 (다중출력)
input_tensor = layers.Input(shape=(2, ))
# hidden layer
x = layers.Dense(units=16, activation='relu')(input_tensor)
x = layers.Dense(units=8, activation='relu')(x)

# output layer
output_tensor1 = layers.Dense(1, name='petal_length_output')(x)
output_tensor2 = layers.Dense(1, name='petal_width_output')(x)
output_tensor3 = layers.Dense(3, activation='softmax', name='species_output')(x)

model = models.Model(input_tensor, [output_tensor1, output_tensor2, output_tensor3])
# input이나 output이 여러개일 경우 List로 묶어서 전달.

# %%
model.summary()
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_9 (InputLayer)           [(None, 2)]          0           []
#
#  dense_10 (Dense)               (None, 16)           48          ['input_9[0][0]']
#
#  dense_11 (Dense)               (None, 8)            136         ['dense_10[0][0]']
#
#  petal_length_output (Dense)    (None, 1)            9           ['dense_11[0][0]']
#
#  petal_width_output (Dense)     (None, 1)            9           ['dense_11[0][0]']
#
#  species_output (Dense)         (None, 3)            27          ['dense_11[0][0]']
#
# ==================================================================================================
# Total params: 229
# Trainable params: 229
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
keras.utils.plot_model(model, show_shapes=True)

# %%
# compile
model.compile(optimizer='adam', 
              loss=["mse", "mse", "sparse_categorical_crossentropy"])
             # 출력결과순서별로 loss를 구해서 모두 더한 Total Loss 를 이용해 최적화작업을 수행한다.

# %%
tf.data.Dataset.from_tensor_slices((X, (y1, y2, y3)))
# Out:
# <TensorSliceDataset element_spec=(TensorSpec(shape=(2,), dtype=tf.float64, name=None), (TensorSpec(shape=(), dtype=tf.float64, name=None), TensorSpec(shape=(), dtype=tf.float64, name=None), TensorSpec(shape=(), dtype=tf.int64, name=None)))>

# %% [markdown]
# ##### 학습

# %%
hist = model.fit(X, 
                 [y1,y2,y3], # y가 여러개이면 리스트로 묶어준다.
                 epochs=100, 
                 validation_split=0.2
                 )
# Out:
# Epoch 1/100
# 4/4 [==============================] - 2s 121ms/step - loss: 5.9148 - petal_length_output_loss: 2.6470 - petal_width_output_loss: 1.1914 - species_output_loss: 2.0765 - val_loss: 12.4809 - val_petal_length_output_loss: 5.5120 - val_petal_width_output_loss: 3.1201 - val_species_output_loss: 3.8488
# Epoch 2/100
# 4/4 [==============================] - 0s 18ms/step - loss: 5.3772 - petal_length_output_loss: 2.3332 - petal_width_output_loss: 0.9844 - species_output_loss: 2.0596 - val_loss: 11.1234 - val_petal_length_output_loss: 4.6144 - val_petal_width_output_loss: 2.6531 - val_species_output_loss: 3.8559
# Epoch 3/100
# 4/4 [==============================] - 0s 21ms/step - loss: 4.9341 - petal_length_output_loss: 2.1135 - petal_width_output_loss: 0.7986 - species_output_loss: 2.0220 - val_loss: 9.9733 - val_petal_length_output_loss: 3.9208 - val_petal_width_output_loss: 2.2245 - val_species_output_loss: 3.8281
# Epoch 4/100
# 4/4 [==============================] - 0s 19ms/step - loss: 4.5832 - petal_length_output_loss: 1.9563 - petal_width_output_loss: 0.6560 - species_output_loss: 1.9709 - val_loss: 8.9812 - val_petal_length_output_loss: 3.3597 - val_petal_width_output_loss: 1.8413 - val_species_output_loss: 3.7802
# Epoch 5/100
# 4/4 [==============================] - 0s 21ms/step - loss: 4.3049 - petal_length_output_loss: 1.8462 - petal_width_output_loss: 0.5416 - species_output_loss: 1.9171 - val_loss: 8.3470 - val_petal_length_output_loss: 3.0746 - val_petal_width_output_loss: 1.5488 - val_species_output_loss: 3.7236
# Epoch 6/100
# 4/4 [==============================] - 0s 19ms/step - loss: 4.1519 - petal_length_output_loss: 1.8022 - petal_width_output_loss: 0.4742 - species_output_loss: 1.8755 - val_loss: 7.9128 - val_petal_length_output_loss: 2.9448 - val_petal_width_output_loss: 1.3150 - val_species_output_loss: 3.6530
# Epoch 7/100
# 4/4 [==============================] - 0s 27ms/step - loss: 4.0309 - petal_length_output_loss: 1.7785 - petal_width_output_loss: 0.4282 - species_output_loss: 1.8241 - val_loss: 7.5963 - val_petal_length_output_loss: 2.9122 - val_petal_width_output_loss: 1.1249 - val_species_output_loss: 3.5592
# Epoch 8/100
# 4/4 [==============================] - 0s 24ms/step - loss: 3.9427 - petal_length_output_loss: 1.7598 - petal_width_output_loss: 0.4070 - species_output_loss: 1.7759 - val_loss: 7.3224 - val_petal_length_output_loss: 2.8916 - val_petal_width_output_loss: 0.9677 - val_species_output_loss: 3.4631
# Epoch 9/100
# 4/4 [==============================] - 0s 24ms/step - loss: 3.8478 - petal_length_output_loss: 1.7418 - petal_width_output_loss: 0.3888 - species_output_loss: 1.7172 - val_loss: 7.1617 - val_petal_length_output_loss: 2.9577 - val_petal_width_output_loss: 0.8522 - val_species_output_loss: 3.3517
# Epoch 10/100
# 4/4 [==============================] - 0s 24ms/step - loss: 3.7699 - petal_length_output_loss: 1.7380 - petal_width_output_loss: 0.3797 - species_output_loss: 1.6522 - val_loss: 7.0835 - val_petal_length_output_loss: 3.0753 - val_petal_width_output_loss: 0.7720 - val_species_output_loss: 3.2361
# Epoch 11/100
# 4/4 [==============================] - 0s 24ms/step - loss: 3.7009 - petal_length_output_loss: 1.7242 - petal_width_output_loss: 0.3786 - species_output_loss: 1.5981 - val_loss: 6.9622 - val_petal_length_output_loss: 3.1063 - val_petal_width_output_loss: 0.7087 - val_species_output_loss: 3.1471
# Epoch 12/100
# 4/4 [==============================] - 0s 24ms/step - loss: 3.6394 - petal_length_output_loss: 1.7087 - petal_width_output_loss: 0.3780 - species_output_loss: 1.5527 - val_loss: 6.8352 - val_petal_length_output_loss: 3.0984 - val_petal_width_output_loss: 0.6637 - val_species_output_loss: 3.0732
# Epoch 13/100
# 4/4 [==============================] - 0s 17ms/step - loss: 3.5802 - petal_length_output_loss: 1.6897 - petal_width_output_loss: 0.3779 - species_output_loss: 1.5126 - val_loss: 6.7107 - val_petal_length_output_loss: 3.0662 - val_petal_width_output_loss: 0.6338 - val_species_output_loss: 3.0107
# Epoch 14/100
# 4/4 [==============================] - 0s 26ms/step - loss: 3.5261 - petal_length_output_loss: 1.6627 - petal_width_output_loss: 0.3784 - species_output_loss: 1.4850 - val_loss: 6.5459 - val_petal_length_output_loss: 2.9662 - val_petal_width_output_loss: 0.6122 - val_species_output_loss: 2.9675
# Epoch 15/100
# 4/4 [==============================] - 0s 18ms/step - loss: 3.4711 - petal_length_output_loss: 1.6332 - petal_width_output_loss: 0.3786 - species_output_loss: 1.4594 - val_loss: 6.3809 - val_petal_length_output_loss: 2.8547 - val_petal_width_output_loss: 0.5979 - val_species_output_loss: 2.9282
# Epoch 16/100
# 4/4 [==============================] - 0s 24ms/step - loss: 3.4221 - petal_length_output_loss: 1.6038 - petal_width_output_loss: 0.3780 - species_output_loss: 1.4403 - val_loss: 6.2110 - val_petal_length_output_loss: 2.7276 - val_petal_width_output_loss: 0.5879 - val_species_output_loss: 2.8955
# Epoch 17/100
# 4/4 [==============================] - 0s 20ms/step - loss: 3.3688 - petal_length_output_loss: 1.5764 - petal_width_output_loss: 0.3761 - species_output_loss: 1.4163 - val_loss: 6.1178 - val_petal_length_output_loss: 2.6770 - val_petal_width_output_loss: 0.5912 - val_species_output_loss: 2.8496
# Epoch 18/100
# 4/4 [==============================] - 0s 20ms/step - loss: 3.3208 - petal_length_output_loss: 1.5512 - petal_width_output_loss: 0.3730 - species_output_loss: 1.3966 - val_loss: 5.9964 - val_petal_length_output_loss: 2.5942 - val_petal_width_output_loss: 0.5911 - val_species_output_loss: 2.8111
# Epoch 19/100
# 4/4 [==============================] - 0s 23ms/step - loss: 3.2724 - petal_length_output_loss: 1.5282 - petal_width_output_loss: 0.3698 - species_output_loss: 1.3744 - val_loss: 5.9214 - val_petal_length_output_loss: 2.5550 - val_petal_width_output_loss: 0.5997 - val_species_output_loss: 2.7667
# Epoch 20/100
# 4/4 [==============================] - 0s 19ms/step - loss: 3.2256 - petal_length_output_loss: 1.5058 - petal_width_output_loss: 0.3658 - species_output_loss: 1.3540 - val_loss: 5.8493 - val_petal_length_output_loss: 2.5164 - val_petal_width_output_loss: 0.6088 - val_species_output_loss: 2.7242
# Epoch 21/100
# 4/4 [==============================] - 0s 17ms/step - loss: 3.1827 - petal_length_output_loss: 1.4844 - petal_width_output_loss: 0.3620 - species_output_loss: 1.3363 - val_loss: 5.7617 - val_petal_length_output_loss: 2.4616 - val_petal_width_output_loss: 0.6147 - val_species_output_loss: 2.6854
# Epoch 22/100
# 4/4 [==============================] - 0s 23ms/step - loss: 3.1403 - petal_length_output_loss: 1.4615 - petal_width_output_loss: 0.3582 - species_output_loss: 1.3206 - val_loss: 5.6717 - val_petal_length_output_loss: 2.4009 - val_petal_width_output_loss: 0.6217 - val_species_output_loss: 2.6491
# Epoch 23/100
# 4/4 [==============================] - 0s 18ms/step - loss: 3.0977 - petal_length_output_loss: 1.4394 - petal_width_output_loss: 0.3545 - species_output_loss: 1.3037 - val_loss: 5.6175 - val_petal_length_output_loss: 2.3770 - val_petal_width_output_loss: 0.6318 - val_species_output_loss: 2.6087
# Epoch 24/100
# 4/4 [==============================] - 0s 22ms/step - loss: 3.0590 - petal_length_output_loss: 1.4184 - petal_width_output_loss: 0.3505 - species_output_loss: 1.2902 - val_loss: 5.5385 - val_petal_length_output_loss: 2.3262 - val_petal_width_output_loss: 0.6378 - val_species_output_loss: 2.5745
# Epoch 25/100
# 4/4 [==============================] - 0s 23ms/step - loss: 3.0212 - petal_length_output_loss: 1.3953 - petal_width_output_loss: 0.3468 - species_output_loss: 1.2791 - val_loss: 5.4383 - val_petal_length_output_loss: 2.2553 - val_petal_width_output_loss: 0.6394 - val_species_output_loss: 2.5436
# Epoch 26/100
# 4/4 [==============================] - 0s 18ms/step - loss: 2.9851 - petal_length_output_loss: 1.3731 - petal_width_output_loss: 0.3433 - species_output_loss: 1.2686 - val_loss: 5.3637 - val_petal_length_output_loss: 2.2083 - val_petal_width_output_loss: 0.6427 - val_species_output_loss: 2.5127
# Epoch 27/100
# 4/4 [==============================] - 0s 26ms/step - loss: 2.9556 - petal_length_output_loss: 1.3528 - petal_width_output_loss: 0.3400 - species_output_loss: 1.2628 - val_loss: 5.2552 - val_petal_length_output_loss: 2.1292 - val_petal_width_output_loss: 0.6390 - val_species_output_loss: 2.4871
# Epoch 28/100
# 4/4 [==============================] - 0s 18ms/step - loss: 2.9178 - petal_length_output_loss: 1.3294 - petal_width_output_loss: 0.3364 - species_output_loss: 1.2521 - val_loss: 5.2399 - val_petal_length_output_loss: 2.1369 - val_petal_width_output_loss: 0.6495 - val_species_output_loss: 2.4535
# Epoch 29/100
# 4/4 [==============================] - 0s 19ms/step - loss: 2.8882 - petal_length_output_loss: 1.3099 - petal_width_output_loss: 0.3323 - species_output_loss: 1.2460 - val_loss: 5.1799 - val_petal_length_output_loss: 2.1038 - val_petal_width_output_loss: 0.6512 - val_species_output_loss: 2.4249
# Epoch 30/100
# 4/4 [==============================] - 0s 23ms/step - loss: 2.8589 - petal_length_output_loss: 1.2906 - petal_width_output_loss: 0.3287 - species_output_loss: 1.2395 - val_loss: 5.1347 - val_petal_length_output_loss: 2.0812 - val_petal_width_output_loss: 0.6559 - val_species_output_loss: 2.3977
# Epoch 31/100
# 4/4 [==============================] - 0s 19ms/step - loss: 2.8342 - petal_length_output_loss: 1.2719 - petal_width_output_loss: 0.3251 - species_output_loss: 1.2372 - val_loss: 5.0146 - val_petal_length_output_loss: 1.9831 - val_petal_width_output_loss: 0.6491 - val_species_output_loss: 2.3824
# Epoch 32/100
# 4/4 [==============================] - 0s 19ms/step - loss: 2.8019 - petal_length_output_loss: 1.2480 - petal_width_output_loss: 0.3215 - species_output_loss: 1.2324 - val_loss: 5.0121 - val_petal_length_output_loss: 1.9976 - val_petal_width_output_loss: 0.6599 - val_species_output_loss: 2.3546
# Epoch 33/100
# 4/4 [==============================] - 0s 19ms/step - loss: 2.7751 - petal_length_output_loss: 1.2273 - petal_width_output_loss: 0.3173 - species_output_loss: 1.2305 - val_loss: 4.9355 - val_petal_length_output_loss: 1.9408 - val_petal_width_output_loss: 0.6582 - val_species_output_loss: 2.3365
# Epoch 34/100
# 4/4 [==============================] - 0s 23ms/step - loss: 2.7487 - petal_length_output_loss: 1.2061 - petal_width_output_loss: 0.3136 - species_output_loss: 1.2290 - val_loss: 4.8587 - val_petal_length_output_loss: 1.8850 - val_petal_width_output_loss: 0.6546 - val_species_output_loss: 2.3191
# Epoch 35/100
# 4/4 [==============================] - 0s 24ms/step - loss: 2.7241 - petal_length_output_loss: 1.1859 - petal_width_output_loss: 0.3098 - species_output_loss: 1.2284 - val_loss: 4.7489 - val_petal_length_output_loss: 1.8025 - val_petal_width_output_loss: 0.6424 - val_species_output_loss: 2.3040
# Epoch 36/100
# 4/4 [==============================] - 0s 23ms/step - loss: 2.6987 - petal_length_output_loss: 1.1645 - petal_width_output_loss: 0.3061 - species_output_loss: 1.2281 - val_loss: 4.6635 - val_petal_length_output_loss: 1.7453 - val_petal_width_output_loss: 0.6324 - val_species_output_loss: 2.2858
# Epoch 37/100
# 4/4 [==============================] - 0s 23ms/step - loss: 2.6754 - petal_length_output_loss: 1.1466 - petal_width_output_loss: 0.3024 - species_output_loss: 1.2264 - val_loss: 4.6407 - val_petal_length_output_loss: 1.7427 - val_petal_width_output_loss: 0.6327 - val_species_output_loss: 2.2653
# Epoch 38/100
# 4/4 [==============================] - 0s 24ms/step - loss: 2.6517 - petal_length_output_loss: 1.1267 - petal_width_output_loss: 0.2982 - species_output_loss: 1.2268 - val_loss: 4.5700 - val_petal_length_output_loss: 1.7013 - val_petal_width_output_loss: 0.6223 - val_species_output_loss: 2.2464
# Epoch 39/100
# 4/4 [==============================] - 0s 24ms/step - loss: 2.6275 - petal_length_output_loss: 1.1072 - petal_width_output_loss: 0.2943 - species_output_loss: 1.2260 - val_loss: 4.5062 - val_petal_length_output_loss: 1.6646 - val_petal_width_output_loss: 0.6140 - val_species_output_loss: 2.2276
# Epoch 40/100
# 4/4 [==============================] - 0s 18ms/step - loss: 2.6046 - petal_length_output_loss: 1.0881 - petal_width_output_loss: 0.2903 - species_output_loss: 1.2261 - val_loss: 4.4451 - val_petal_length_output_loss: 1.6273 - val_petal_width_output_loss: 0.6071 - val_species_output_loss: 2.2107
# Epoch 41/100
# 4/4 [==============================] - 0s 23ms/step - loss: 2.5821 - petal_length_output_loss: 1.0701 - petal_width_output_loss: 0.2863 - species_output_loss: 1.2257 - val_loss: 4.4114 - val_petal_length_output_loss: 1.6134 - val_petal_width_output_loss: 0.6056 - val_species_output_loss: 2.1923
# Epoch 42/100
# 4/4 [==============================] - 0s 19ms/step - loss: 2.5593 - petal_length_output_loss: 1.0513 - petal_width_output_loss: 0.2821 - species_output_loss: 1.2258 - val_loss: 4.3732 - val_petal_length_output_loss: 1.5951 - val_petal_width_output_loss: 0.6031 - val_species_output_loss: 2.1750
# Epoch 43/100
# 4/4 [==============================] - 0s 26ms/step - loss: 2.5367 - petal_length_output_loss: 1.0337 - petal_width_output_loss: 0.2766 - species_output_loss: 1.2264 - val_loss: 4.3178 - val_petal_length_output_loss: 1.5599 - val_petal_width_output_loss: 0.5985 - val_species_output_loss: 2.1595
# Epoch 44/100
# 4/4 [==============================] - 0s 18ms/step - loss: 2.5131 - petal_length_output_loss: 1.0167 - petal_width_output_loss: 0.2688 - species_output_loss: 1.2276 - val_loss: 4.2856 - val_petal_length_output_loss: 1.5480 - val_petal_width_output_loss: 0.5945 - val_species_output_loss: 2.1431
# Epoch 45/100
# 4/4 [==============================] - 0s 17ms/step - loss: 2.4899 - petal_length_output_loss: 1.0080 - petal_width_output_loss: 0.2524 - species_output_loss: 1.2295 - val_loss: 4.2891 - val_petal_length_output_loss: 1.5698 - val_petal_width_output_loss: 0.5979 - val_species_output_loss: 2.1214
# Epoch 46/100
# 4/4 [==============================] - 0s 19ms/step - loss: 2.4573 - petal_length_output_loss: 1.0040 - petal_width_output_loss: 0.2169 - species_output_loss: 1.2365 - val_loss: 4.2086 - val_petal_length_output_loss: 1.5255 - val_petal_width_output_loss: 0.5783 - val_species_output_loss: 2.1048
# Epoch 47/100
# 4/4 [==============================] - 0s 18ms/step - loss: 2.4269 - petal_length_output_loss: 1.0021 - petal_width_output_loss: 0.1821 - species_output_loss: 1.2427 - val_loss: 4.1284 - val_petal_length_output_loss: 1.4848 - val_petal_width_output_loss: 0.5540 - val_species_output_loss: 2.0896
# Epoch 48/100
# 4/4 [==============================] - 0s 18ms/step - loss: 2.4012 - petal_length_output_loss: 0.9925 - petal_width_output_loss: 0.1636 - species_output_loss: 1.2452 - val_loss: 4.0148 - val_petal_length_output_loss: 1.4277 - val_petal_width_output_loss: 0.5147 - val_species_output_loss: 2.0724
# Epoch 49/100
# 4/4 [==============================] - 0s 17ms/step - loss: 2.3711 - petal_length_output_loss: 0.9707 - petal_width_output_loss: 0.1581 - species_output_loss: 1.2423 - val_loss: 3.9097 - val_petal_length_output_loss: 1.3951 - val_petal_width_output_loss: 0.4657 - val_species_output_loss: 2.0488
# Epoch 50/100
# 4/4 [==============================] - 0s 22ms/step - loss: 2.3446 - petal_length_output_loss: 0.9476 - petal_width_output_loss: 0.1577 - species_output_loss: 1.2393 - val_loss: 3.8400 - val_petal_length_output_loss: 1.3837 - val_petal_width_output_loss: 0.4325 - val_species_output_loss: 2.0238
# Epoch 51/100
# 4/4 [==============================] - 0s 22ms/step - loss: 2.3160 - petal_length_output_loss: 0.9300 - petal_width_output_loss: 0.1484 - species_output_loss: 1.2376 - val_loss: 3.8401 - val_petal_length_output_loss: 1.4164 - val_petal_width_output_loss: 0.4249 - val_species_output_loss: 1.9989
# Epoch 52/100
# 4/4 [==============================] - 0s 17ms/step - loss: 2.2913 - petal_length_output_loss: 0.9162 - petal_width_output_loss: 0.1387 - species_output_loss: 1.2364 - val_loss: 3.8537 - val_petal_length_output_loss: 1.4510 - val_petal_width_output_loss: 0.4233 - val_species_output_loss: 1.9793
# Epoch 53/100
# 4/4 [==============================] - 0s 19ms/step - loss: 2.2663 - petal_length_output_loss: 0.8984 - petal_width_output_loss: 0.1340 - species_output_loss: 1.2339 - val_loss: 3.7791 - val_petal_length_output_loss: 1.4224 - val_petal_width_output_loss: 0.3956 - val_species_output_loss: 1.9610
# Epoch 54/100
# 4/4 [==============================] - 0s 19ms/step - loss: 2.2405 - petal_length_output_loss: 0.8763 - petal_width_output_loss: 0.1330 - species_output_loss: 1.2312 - val_loss: 3.6725 - val_petal_length_output_loss: 1.3532 - val_petal_width_output_loss: 0.3707 - val_species_output_loss: 1.9487
# Epoch 55/100
# 4/4 [==============================] - 0s 23ms/step - loss: 2.2160 - petal_length_output_loss: 0.8569 - petal_width_output_loss: 0.1304 - species_output_loss: 1.2286 - val_loss: 3.6513 - val_petal_length_output_loss: 1.3440 - val_petal_width_output_loss: 0.3711 - val_species_output_loss: 1.9362
# Epoch 56/100
# 4/4 [==============================] - 0s 18ms/step - loss: 2.1922 - petal_length_output_loss: 0.8407 - petal_width_output_loss: 0.1261 - species_output_loss: 1.2254 - val_loss: 3.6018 - val_petal_length_output_loss: 1.3030 - val_petal_width_output_loss: 0.3698 - val_species_output_loss: 1.9291
# Epoch 57/100
# 4/4 [==============================] - 0s 19ms/step - loss: 2.1695 - petal_length_output_loss: 0.8236 - petal_width_output_loss: 0.1235 - species_output_loss: 1.2224 - val_loss: 3.5364 - val_petal_length_output_loss: 1.2561 - val_petal_width_output_loss: 0.3603 - val_species_output_loss: 1.9201
# Epoch 58/100
# 4/4 [==============================] - 0s 23ms/step - loss: 2.1458 - petal_length_output_loss: 0.8051 - petal_width_output_loss: 0.1212 - species_output_loss: 1.2195 - val_loss: 3.5078 - val_petal_length_output_loss: 1.2449 - val_petal_width_output_loss: 0.3546 - val_species_output_loss: 1.9082
# Epoch 59/100
# 4/4 [==============================] - 0s 24ms/step - loss: 2.1273 - petal_length_output_loss: 0.7912 - petal_width_output_loss: 0.1199 - species_output_loss: 1.2163 - val_loss: 3.5075 - val_petal_length_output_loss: 1.2652 - val_petal_width_output_loss: 0.3505 - val_species_output_loss: 1.8917
# Epoch 60/100
# 4/4 [==============================] - 0s 18ms/step - loss: 2.1049 - petal_length_output_loss: 0.7738 - petal_width_output_loss: 0.1179 - species_output_loss: 1.2131 - val_loss: 3.4012 - val_petal_length_output_loss: 1.1882 - val_petal_width_output_loss: 0.3311 - val_species_output_loss: 1.8819
# Epoch 61/100
# 4/4 [==============================] - 0s 29ms/step - loss: 2.0832 - petal_length_output_loss: 0.7566 - petal_width_output_loss: 0.1163 - species_output_loss: 1.2103 - val_loss: 3.3600 - val_petal_length_output_loss: 1.1631 - val_petal_width_output_loss: 0.3258 - val_species_output_loss: 1.8711
# Epoch 62/100
# 4/4 [==============================] - 0s 26ms/step - loss: 2.0638 - petal_length_output_loss: 0.7416 - petal_width_output_loss: 0.1155 - species_output_loss: 1.2067 - val_loss: 3.3521 - val_petal_length_output_loss: 1.1690 - val_petal_width_output_loss: 0.3264 - val_species_output_loss: 1.8566
# Epoch 63/100
# 4/4 [==============================] - 0s 18ms/step - loss: 2.0439 - petal_length_output_loss: 0.7264 - petal_width_output_loss: 0.1144 - species_output_loss: 1.2031 - val_loss: 3.3293 - val_petal_length_output_loss: 1.1658 - val_petal_width_output_loss: 0.3219 - val_species_output_loss: 1.8415
# Epoch 64/100
# 4/4 [==============================] - 0s 18ms/step - loss: 2.0289 - petal_length_output_loss: 0.7149 - petal_width_output_loss: 0.1140 - species_output_loss: 1.2001 - val_loss: 3.2331 - val_petal_length_output_loss: 1.1004 - val_petal_width_output_loss: 0.3046 - val_species_output_loss: 1.8280
# Epoch 65/100
# 4/4 [==============================] - 0s 18ms/step - loss: 2.0063 - petal_length_output_loss: 0.6976 - petal_width_output_loss: 0.1123 - species_output_loss: 1.1964 - val_loss: 3.2408 - val_petal_length_output_loss: 1.1163 - val_petal_width_output_loss: 0.3095 - val_species_output_loss: 1.8149
# Epoch 66/100
# 4/4 [==============================] - 0s 24ms/step - loss: 1.9892 - petal_length_output_loss: 0.6845 - petal_width_output_loss: 0.1127 - species_output_loss: 1.1920 - val_loss: 3.2450 - val_petal_length_output_loss: 1.1257 - val_petal_width_output_loss: 0.3157 - val_species_output_loss: 1.8036
# Epoch 67/100
# 4/4 [==============================] - 0s 24ms/step - loss: 1.9742 - petal_length_output_loss: 0.6724 - petal_width_output_loss: 0.1143 - species_output_loss: 1.1875 - val_loss: 3.2249 - val_petal_length_output_loss: 1.1166 - val_petal_width_output_loss: 0.3140 - val_species_output_loss: 1.7944
# Epoch 68/100
# 4/4 [==============================] - 0s 23ms/step - loss: 1.9550 - petal_length_output_loss: 0.6590 - petal_width_output_loss: 0.1119 - species_output_loss: 1.1841 - val_loss: 3.0947 - val_petal_length_output_loss: 1.0267 - val_petal_width_output_loss: 0.2845 - val_species_output_loss: 1.7835
# Epoch 69/100
# 4/4 [==============================] - 0s 22ms/step - loss: 1.9418 - petal_length_output_loss: 0.6491 - petal_width_output_loss: 0.1111 - species_output_loss: 1.1816 - val_loss: 3.0244 - val_petal_length_output_loss: 0.9753 - val_petal_width_output_loss: 0.2731 - val_species_output_loss: 1.7761
# Epoch 70/100
# 4/4 [==============================] - 0s 18ms/step - loss: 1.9237 - petal_length_output_loss: 0.6355 - petal_width_output_loss: 0.1105 - species_output_loss: 1.1777 - val_loss: 3.0546 - val_petal_length_output_loss: 1.0048 - val_petal_width_output_loss: 0.2844 - val_species_output_loss: 1.7654
# Epoch 71/100
# 4/4 [==============================] - 0s 21ms/step - loss: 1.9070 - petal_length_output_loss: 0.6234 - petal_width_output_loss: 0.1123 - species_output_loss: 1.1713 - val_loss: 3.1189 - val_petal_length_output_loss: 1.0578 - val_petal_width_output_loss: 0.3050 - val_species_output_loss: 1.7561
# Epoch 72/100
# 4/4 [==============================] - 0s 24ms/step - loss: 1.8950 - petal_length_output_loss: 0.6129 - petal_width_output_loss: 0.1164 - species_output_loss: 1.1657 - val_loss: 3.1245 - val_petal_length_output_loss: 1.0700 - val_petal_width_output_loss: 0.3072 - val_species_output_loss: 1.7474
# Epoch 73/100
# 4/4 [==============================] - 0s 18ms/step - loss: 1.8799 - petal_length_output_loss: 0.6036 - petal_width_output_loss: 0.1150 - species_output_loss: 1.1613 - val_loss: 3.0564 - val_petal_length_output_loss: 1.0315 - val_petal_width_output_loss: 0.2879 - val_species_output_loss: 1.7370
# Epoch 74/100
# 4/4 [==============================] - 0s 23ms/step - loss: 1.8640 - petal_length_output_loss: 0.5931 - petal_width_output_loss: 0.1119 - species_output_loss: 1.1591 - val_loss: 2.9199 - val_petal_length_output_loss: 0.9245 - val_petal_width_output_loss: 0.2608 - val_species_output_loss: 1.7345
# Epoch 75/100
# 4/4 [==============================] - 0s 25ms/step - loss: 1.8510 - petal_length_output_loss: 0.5838 - petal_width_output_loss: 0.1112 - species_output_loss: 1.1560 - val_loss: 2.8902 - val_petal_length_output_loss: 0.9023 - val_petal_width_output_loss: 0.2613 - val_species_output_loss: 1.7267
# Epoch 76/100
# 4/4 [==============================] - 0s 19ms/step - loss: 1.8362 - petal_length_output_loss: 0.5744 - petal_width_output_loss: 0.1119 - species_output_loss: 1.1499 - val_loss: 2.9083 - val_petal_length_output_loss: 0.9164 - val_petal_width_output_loss: 0.2711 - val_species_output_loss: 1.7208
# Epoch 77/100
# 4/4 [==============================] - 0s 24ms/step - loss: 1.8208 - petal_length_output_loss: 0.5645 - petal_width_output_loss: 0.1131 - species_output_loss: 1.1432 - val_loss: 2.9235 - val_petal_length_output_loss: 0.9332 - val_petal_width_output_loss: 0.2764 - val_species_output_loss: 1.7139
# Epoch 78/100
# 4/4 [==============================] - 0s 18ms/step - loss: 1.8100 - petal_length_output_loss: 0.5571 - petal_width_output_loss: 0.1156 - species_output_loss: 1.1373 - val_loss: 2.9407 - val_petal_length_output_loss: 0.9538 - val_petal_width_output_loss: 0.2815 - val_species_output_loss: 1.7054
# Epoch 79/100
# 4/4 [==============================] - 0s 19ms/step - loss: 1.7952 - petal_length_output_loss: 0.5469 - petal_width_output_loss: 0.1157 - species_output_loss: 1.1326 - val_loss: 2.8755 - val_petal_length_output_loss: 0.9069 - val_petal_width_output_loss: 0.2698 - val_species_output_loss: 1.6989
# Epoch 80/100
# 4/4 [==============================] - 0s 28ms/step - loss: 1.7832 - petal_length_output_loss: 0.5398 - petal_width_output_loss: 0.1152 - species_output_loss: 1.1282 - val_loss: 2.8059 - val_petal_length_output_loss: 0.8565 - val_petal_width_output_loss: 0.2575 - val_species_output_loss: 1.6919
# Epoch 81/100
# 4/4 [==============================] - 0s 18ms/step - loss: 1.7716 - petal_length_output_loss: 0.5330 - petal_width_output_loss: 0.1153 - species_output_loss: 1.1232 - val_loss: 2.8196 - val_petal_length_output_loss: 0.8743 - val_petal_width_output_loss: 0.2627 - val_species_output_loss: 1.6827
# Epoch 82/100
# 4/4 [==============================] - 0s 20ms/step - loss: 1.7587 - petal_length_output_loss: 0.5252 - petal_width_output_loss: 0.1163 - species_output_loss: 1.1172 - val_loss: 2.8113 - val_petal_length_output_loss: 0.8749 - val_petal_width_output_loss: 0.2626 - val_species_output_loss: 1.6738
# Epoch 83/100
# 4/4 [==============================] - 0s 24ms/step - loss: 1.7462 - petal_length_output_loss: 0.5176 - petal_width_output_loss: 0.1164 - species_output_loss: 1.1122 - val_loss: 2.7619 - val_petal_length_output_loss: 0.8392 - val_petal_width_output_loss: 0.2550 - val_species_output_loss: 1.6677
# Epoch 84/100
# 4/4 [==============================] - 0s 18ms/step - loss: 1.7356 - petal_length_output_loss: 0.5120 - petal_width_output_loss: 0.1166 - species_output_loss: 1.1070 - val_loss: 2.7383 - val_petal_length_output_loss: 0.8232 - val_petal_width_output_loss: 0.2547 - val_species_output_loss: 1.6603
# Epoch 85/100
# 4/4 [==============================] - 0s 19ms/step - loss: 1.7248 - petal_length_output_loss: 0.5061 - petal_width_output_loss: 0.1187 - species_output_loss: 1.1000 - val_loss: 2.7839 - val_petal_length_output_loss: 0.8629 - val_petal_width_output_loss: 0.2682 - val_species_output_loss: 1.6528
# Epoch 86/100
# 4/4 [==============================] - 0s 24ms/step - loss: 1.7129 - petal_length_output_loss: 0.4979 - petal_width_output_loss: 0.1217 - species_output_loss: 1.0933 - val_loss: 2.7579 - val_petal_length_output_loss: 0.8467 - val_petal_width_output_loss: 0.2666 - val_species_output_loss: 1.6446
# Epoch 87/100
# 4/4 [==============================] - 0s 24ms/step - loss: 1.7015 - petal_length_output_loss: 0.4922 - petal_width_output_loss: 0.1212 - species_output_loss: 1.0881 - val_loss: 2.7072 - val_petal_length_output_loss: 0.8148 - val_petal_width_output_loss: 0.2564 - val_species_output_loss: 1.6360
# Epoch 88/100
# 4/4 [==============================] - 0s 20ms/step - loss: 1.6903 - petal_length_output_loss: 0.4873 - petal_width_output_loss: 0.1190 - species_output_loss: 1.0840 - val_loss: 2.6632 - val_petal_length_output_loss: 0.7851 - val_petal_width_output_loss: 0.2486 - val_species_output_loss: 1.6295
# Epoch 89/100
# 4/4 [==============================] - 0s 19ms/step - loss: 1.6800 - petal_length_output_loss: 0.4827 - petal_width_output_loss: 0.1182 - species_output_loss: 1.0791 - val_loss: 2.6618 - val_petal_length_output_loss: 0.7891 - val_petal_width_output_loss: 0.2505 - val_species_output_loss: 1.6222
# Epoch 90/100
# 4/4 [==============================] - 0s 21ms/step - loss: 1.6689 - petal_length_output_loss: 0.4772 - petal_width_output_loss: 0.1194 - species_output_loss: 1.0723 - val_loss: 2.6685 - val_petal_length_output_loss: 0.7960 - val_petal_width_output_loss: 0.2560 - val_species_output_loss: 1.6165
# Epoch 91/100
# 4/4 [==============================] - 0s 21ms/step - loss: 1.6599 - petal_length_output_loss: 0.4722 - petal_width_output_loss: 0.1229 - species_output_loss: 1.0647 - val_loss: 2.6819 - val_petal_length_output_loss: 0.8082 - val_petal_width_output_loss: 0.2644 - val_species_output_loss: 1.6092
# Epoch 92/100
# 4/4 [==============================] - 0s 23ms/step - loss: 1.6519 - petal_length_output_loss: 0.4685 - petal_width_output_loss: 0.1255 - species_output_loss: 1.0579 - val_loss: 2.6593 - val_petal_length_output_loss: 0.7957 - val_petal_width_output_loss: 0.2616 - val_species_output_loss: 1.6020
# Epoch 93/100
# 4/4 [==============================] - 0s 19ms/step - loss: 1.6389 - petal_length_output_loss: 0.4630 - petal_width_output_loss: 0.1228 - species_output_loss: 1.0531 - val_loss: 2.6042 - val_petal_length_output_loss: 0.7593 - val_petal_width_output_loss: 0.2508 - val_species_output_loss: 1.5941
# Epoch 94/100
# 4/4 [==============================] - 0s 19ms/step - loss: 1.6299 - petal_length_output_loss: 0.4599 - petal_width_output_loss: 0.1205 - species_output_loss: 1.0495 - val_loss: 2.5519 - val_petal_length_output_loss: 0.7222 - val_petal_width_output_loss: 0.2414 - val_species_output_loss: 1.5883
# Epoch 95/100
# 4/4 [==============================] - 0s 21ms/step - loss: 1.6214 - petal_length_output_loss: 0.4574 - petal_width_output_loss: 0.1197 - species_output_loss: 1.0443 - val_loss: 2.5610 - val_petal_length_output_loss: 0.7318 - val_petal_width_output_loss: 0.2459 - val_species_output_loss: 1.5834
# Epoch 96/100
# 4/4 [==============================] - 0s 25ms/step - loss: 1.6131 - petal_length_output_loss: 0.4541 - petal_width_output_loss: 0.1230 - species_output_loss: 1.0361 - val_loss: 2.6003 - val_petal_length_output_loss: 0.7648 - val_petal_width_output_loss: 0.2577 - val_species_output_loss: 1.5778
# Epoch 97/100
# 4/4 [==============================] - 0s 22ms/step - loss: 1.6019 - petal_length_output_loss: 0.4486 - petal_width_output_loss: 0.1252 - species_output_loss: 1.0281 - val_loss: 2.5755 - val_petal_length_output_loss: 0.7473 - val_petal_width_output_loss: 0.2550 - val_species_output_loss: 1.5731
# Epoch 98/100
# 4/4 [==============================] - 0s 27ms/step - loss: 1.5937 - petal_length_output_loss: 0.4469 - petal_width_output_loss: 0.1238 - species_output_loss: 1.0230 - val_loss: 2.5177 - val_petal_length_output_loss: 0.7058 - val_petal_width_output_loss: 0.2456 - val_species_output_loss: 1.5663
# Epoch 99/100
# 4/4 [==============================] - 0s 26ms/step - loss: 1.5832 - petal_length_output_loss: 0.4429 - petal_width_output_loss: 0.1226 - species_output_loss: 1.0177 - val_loss: 2.5252 - val_petal_length_output_loss: 0.7166 - val_petal_width_output_loss: 0.2486 - val_species_output_loss: 1.5600
# Epoch 100/100
# 4/4 [==============================] - 0s 26ms/step - loss: 1.5753 - petal_length_output_loss: 0.4403 - petal_width_output_loss: 0.1251 - species_output_loss: 1.0099 - val_loss: 2.5819 - val_petal_length_output_loss: 0.7649 - val_petal_width_output_loss: 0.2602 - val_species_output_loss: 1.5568

# %%
loss: 35.6906 - 
    petal_length_output_loss: 31.9710 - petal_width_output_loss: 2.5700 - species_output_loss: 1.1496 
                
- val_loss: 67.1428 - val_petal_length_output_loss: 59.6820 - val_petal_width_output_loss: 6.0121 - val_species_output_loss: 1.4487

# %%
loss: 3.5857 - petal_length_output_loss: 2.3520 - petal_width_output_loss: 0.3025 - species_output_loss: 0.9312 

- val_loss: 5.9203 - val_petal_length_output_loss: 3.4391 - val_petal_width_output_loss: 0.6980 - val_species_output_loss: 1.7831

# %% [markdown]
# ##### 결과 시각화

# %%
hist.history.keys()
# Out:
# dict_keys(['loss', 'petal_length_output_loss', 'petal_width_output_loss', 'species_output_loss', 'val_loss', 'val_petal_length_output_loss', 'val_petal_width_output_loss', 'val_species_output_loss'])

# %% [markdown]
# ##### 새로운 데이터 추론

# %%
new_x = X[:3]
pred = model.predict(new_x)
pred  # 세 layer의 출력결과를 리스트로 묶어서 출력.
# Out:
# 1/1 [==============================] - 0s 96ms/step
# [array([[1.9474657],
#         [2.3610058],
#         [1.7931014]], dtype=float32), array([[0.18316704],
#         [0.5297893 ],
#         [0.17449296]], dtype=float32), array([[0.39114496, 0.4639674 , 0.14488763],
#         [0.368175  , 0.4509206 , 0.18090433],
#         [0.38349065, 0.45998368, 0.15652572]], dtype=float32)]

# %%
for pl, pw, s in zip(pred[0], pred[1], pred[2]):  #### 선생님 것 . 결과값이 선생님 것과 상이 ###
  print(pl, pw, s, s.argmax(-1))
# Out:
# [1.9474657] [0.18316704] [0.39114496 0.4639674  0.14488763] 1
# [2.3610058] [0.5297893] [0.368175   0.4509206  0.18090433] 1
# [1.7931014] [0.17449296] [0.38349065 0.45998368 0.15652572] 1

# %%
y[:3]
# Out:
# array([0, 0, 0])

# %% [markdown]
# ## 다중 입력 모델
# - 가정
#     - IRIS 꽃 데이터 + 꽃의 사진을 입력해서 꽃의 종류를 예측한다.
# - X: 꽃 데이터, 꽃 사진
# - y: 꽃 종류

# %% [markdown]
# ##### 데이터 로드

# %%
X, y = load_iris(return_X_y=True)
X.shape, y.shape
# Out:
# ((150, 4), (150,))

# %%
(X_train, _), (_, _) = keras.datasets.mnist.load_data()
X_img = X_train[:150]
X_train.shape, X_img.shape
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# ((60000, 28, 28), (150, 28, 28))

# %% [markdown]
# ##### 모델생성, 컴파일

# %%
# table 데이터와 영상데이터 두개를 입력으로 받는 모델.
# table 데이터는 Dense Layer를, 영상데이터는 Conv layer를 이용해 Feature Extraction을 처리.
# 추출된 두가지 특징을 합쳐서 품종을 추론하는 모델.

iris_info_tensor = layers.Input(shape=(4, ))
x1 = layers.Dense(units=32, activation='relu')(iris_info_tensor)
x1 = layers.Dense(units=16, activation='relu')(x1)

iris_img_tensor = layers.Input(shape=(28, 28, 1))
x2 = layers.Conv2D(filters=32, kernel_size=3, padding='same', activation='relu')(iris_img_tensor)
x2 = layers.Conv2D(filters=32, kernel_size=3, padding='same', activation='relu')(x2)
x2 = layers.MaxPooling2D(padding='same')(x2)

x2 = layers.Conv2D(filters=64, kernel_size=3, padding='same', activation='relu')(x2)
x2 = layers.Conv2D(filters=64, kernel_size=3, padding='same', activation='relu')(x2)
x2 = layers.MaxPooling2D(padding='same')(x2)
x2 = layers.Flatten()(x2)

# x1과 x2를 합치기 -> 둘다 1차원 배열. ===> info의 특징과 image의 특징을 합친다.
x3 = layers.Concatenate()([x1, x2])  # layers.concatenate([x1, x2])

# outputlayer
output_tensor = layers.Dense(units=3, activation='softmax')(x3)

# 모델 생성
model2 = models.Model([iris_info_tensor, iris_img_tensor],  output_tensor)

model2.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
X_img.shape
# Out:
# (150, 28, 28)

# %%
import numpy as np
iris_img = X_img[..., np.newaxis]
iris_img.shape
# Out:
# (150, 28, 28, 1)

# %%
hist= model2.fit([X, iris_img], 
                  y, 
                  epochs=3, 
                  validation_split=0.2)
# Out:
# Epoch 1/3
# 4/4 [==============================] - 3s 243ms/step - loss: 9.6678 - accuracy: 0.3583 - val_loss: 12.6006 - val_accuracy: 0.0333
# Epoch 2/3
# 4/4 [==============================] - 1s 155ms/step - loss: 2.8214 - accuracy: 0.3750 - val_loss: 1.6163 - val_accuracy: 0.4000
# Epoch 3/3
# 4/4 [==============================] - 1s 336ms/step - loss: 1.2266 - accuracy: 0.5083 - val_loss: 4.4547 - val_accuracy: 0.0000e+00

# %%
keras.utils.plot_model(model2, show_shapes=True)

# %% [markdown]
# ## Subclass 방식
# - 모델을 class로 구현
# -\_\_init\_\_() 메소드에서 모델에 필요한 자원들(layer)을 생성
# - call() 메소드에서 모델 구조 정의

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models

# %%
(X_train, y_train), (X_test, y_test) = keras.datasets.mnist.load_data()
X_train = X_train.astype('float32')/255
X_test = X_test.astype('float32')/255

X_train = X_train[..., np.newaxis]
X_test = X_test[..., np.newaxis]
X_train.shape, X_test.shape
# Out:
# ((60000, 28, 28, 1), (10000, 28, 28, 1))

# %%
class MnistModel(models.Model):
    
    def __init__(self):
        super().__init__()
        self.conv_block1 = keras.Sequential([
            layers.Conv2D(filters=32, kernel_size=3, padding='same', activation='relu'),
            layers.Conv2D(filters=32, kernel_size=3, padding='same', activation='relu'),
            layers.MaxPooling2D(padding='same')
        ])
        
        self.conv_block2 = keras.Sequential([
            layers.Conv2D(filters=64, kernel_size=3, padding='same', activation='relu'),
            layers.Conv2D(filters=64, kernel_size=3, padding='same', activation='relu'),
            layers.MaxPooling2D(padding='same')
        ])
        
        self.flatten = layers.Flatten()
        self.output_layer = layers.Dense(units=10, activation='softmax')        
        
        
    def call(self, x):  
        # input data를 받아서 forward propagation을 처리. 그 추론 결과를 반환
        x = self.conv_block1(x)
        x = self.conv_block2(x)
        x = self.flatten(x)
        output_tensor = self.output_layer(x)
        return output_tensor

# %%
# 모델생성
model = MnistModel()

# 컴파일
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy')
# 학습
hist = model.fit(X_train, y_train, epochs=3, validation_split=0.25)
# Out:
# Epoch 1/3
# 1407/1407 [==============================] - 238s 168ms/step - loss: 0.1437 - val_loss: 0.0532
# Epoch 2/3
# 1407/1407 [==============================] - 228s 162ms/step - loss: 0.0453 - val_loss: 0.0471
# Epoch 3/3
# 1407/1407 [==============================] - 231s 164ms/step - loss: 0.0317 - val_loss: 0.0353

# %%
60000*0.75/32
# Out:
# 1406.25
