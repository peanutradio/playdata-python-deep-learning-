# %% [markdown]
# # DNN (Deep Neural Network)
#
# ## 신경망 구성요소

# %% [markdown]
# ### Train(학습) 프로세스
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### 학습 단계 및 역할
# 1. 모델: 추론
#     - batch size 단위로 추론한다.
# 2. 손실함수(Loss Function): 모델이 추론한 것과 정답간의 Loss(손실-오차)의 평균을 구한다.
# 3. 옵티마이저(Optimizer): 손실함수가 구한 Loss를 기반으로 모델의 파라미터들(weight)을 업데이트한다.

# %% [markdown]
# - <span style='font-size:1.1em;font-weight:bold'>층(Layer)</span>: 모델이 추론하기 위한 각 단계를 정의
# - <span style='font-size:1.1em;font-weight:bold'>손실함수(loss function)</span>: 모델의 예측결과와 Ground truth(실제정답) 사이의 차이를 계산
# - <span style='font-size:1.1em;font-weight:bold'>optimizer</span>: 파라미터(가중치)를 업데이트하여 모델의 성능을 최적화

# %% [markdown]
# ## 유닛/노드/뉴런 (Unit, Node, Neuron)
# - 입력 Feature들을 입력받아 처리 후 출력하는 데이터 처리 모듈
#     - Input -> Output
# - 입력 값에 Weight(가중치)를 곱하고 bias(편향)을 더한 결과를 Activation 함수에 넣어 최종 결과를 출력하는 계산을 처리한다
# -
#
#     ![image.png](attachment:image.png)
#     - **Input vector(입력값)**: $\large\mathbb x=(x_1, x_2, x_3)^T$
#     - **Weights(가중치)**: $\large\mathbb w = (w_1, w_2, w_3)^T$
#     - **Bias(편향)**: $\large b \in \mathbb R$
#     - **Activation function(활성함수)**: $\large\sigma(\cdot)$
#         - 선형결합한 결과를 비선형화 시키는 목적
#         - 다양한 비선형 함수들을 사용한다.
#
#        <center> $\LARGE z=w_1 x_1 + w_2 x_2 + w_3 x_3 + b \Leftrightarrow z = \mathbb w^T \mathbb x + b$ <br><br>
#        $\LARGE a=\sigma( z)$

# %% [markdown]
# ## 레이어/층(Layer)
# - 네트워크 모델의 각 처리단계를 정의한 것.
#     - 실제 처리를 담당하는 Unit들을 모아놓은 구조

# %% [markdown]
# - **Input Layer(입력층)**
#     - 입력값들을 받아 Hidden Layer에 전달하는 노드들로 구성된 Layer.
#     - 입력 데이터의 shape을 설정하는 역할을 한다.

# %% [markdown]
# - **Output Layer(출력층)**
#     - 모델의 최종 예측결과를 출력하는 노드들로 구성된 Layer

# %% [markdown]
# - **Hidden Layer(은닉층)**
#     - Input Layer와 Output Layer사이에 존재하는 Layer.

# %% [markdown]
# - 대부분 Layer들은 학습을 통해 최적화할 Paramter를 가짐
#     - Dropout, Pooling Layer와 같이 Parameter가 없는 layer도 있다.

# %% [markdown]
# - Layer들의 연결한 것을 **<font size=5>Network</font>** 라고 한다.
#     - 딥러닝은 Layer들을 깊게 쌓은 것을 말한다.(여러 Layer들을 연결한 것)

# %% [markdown]
# - 목적, 구현 방식에 따라 다양한 종류의 Layer들이 있다.
#     - **Fully Connected Layer (Dense layer)**
#         - 추론 단계에서 주로 사용
#     - **Convolution Layer**
#         - 이미지 Feature extraction으로 주로 사용
#     - **Recurrent Layer**
#         - Sequential(순차) 데이터의 Feature extraction으로 주로 사용
#     - **Embedding Layer**
#         - Text 데이터의 Feature extraction으로 주로 사용

# %% [markdown]
# - **API**
#     - https://keras.io/api/layers/
#     - https://www.tensorflow.org/api_docs/python/tf/keras/layers

# %% [markdown]
# ## 모델 (Network)
# - Layer를 연결한 것이 Deep learning 모델다.
# - 이전 레이어의 출력을 input으로 받아 처리 후 output으로 출력하는 레이어들을 연결한다.
# - 적절한 network 구조(architecture)를 찾는 것은 공학적이기 보다는 경험적(Art)접근이 필요하다.
#
# ![image-2.png](attachment:image-2.png)
# - **API**
#     - https://keras.io/api/models/
#     - https://www.tensorflow.org/api_docs/python/tf/keras/models

# %% [markdown]
# ## 활성 함수 (Activation Function)
# - 각 유닛이 입력과 Weight간에 가중합을 구한 뒤 출력결과를 만들기 위해 거치는 함수
# - 같은 층(layer)의 모든 유닛들은 같은 활성 함수를 가진다.
# - **출력 레이어**의 경우 출력하려는 문제에 맞춰 활성함수를 결정한다.
# - **은닉층 (Hidden Layer)**의 경우 비선형성을 주어 각 Layer가 처리하는 일을 분리하는 것을 목적으로 한다.
#     - 비선형함수를 사용하지 않으면 Layer들을 여러개 추가하는 의미가 없어진다.
#     - **ReLU** 함수를 주로 사용한다.

# %% [markdown]
# ### 주요 활성함수(Activation Function)
#
# - ### Sigmoid (logistic function)
#     ![image-2.png](attachment:image-2.png)
#
#     - $$\large \sigma(z) = \frac 1 {1+e^{-z}}$$
#     - 출력값의 범위
#         - $0<sigmoid(z)<1$
#     - 한계
#         - 초기 딥러닝의 hidden layer(은닉층)의 activation function(활성함수)로 많이 사용 되었다.
#         - 층을 깊게 쌓을 경우 **기울기 소실(Gradient Vanishing)** 문제를 발생시켜 학습이 안되는 문제가 있다.
#     - **Binary classification(이진 분류)를 위한 네트워크의 Output layer(출력층)의 활성함수로 사용된다.**
#         - 모델이 positive(1)의 확률을 출력결과로 추론하도록 할 경우 사용. (unit개수 1, activation함수 sigmoid)
#         - 위와 같은 한계때문에 hidden layer(은닉층)의 activation function(활성함수)로는 잘 사용되지 않는다.
#
# > **<font size=5>기울기 소실(Gradient Vanishing) 문제란</font>**
# > - 최적화 과정에서 gradient가 0이 되어서 Bottom Layer의 가중치들이 학습이 안되는 현상
# >     - Bottom Layer: Input Layer(입력층)에 가까이 있는 Layer들.
# >     - Top layer: Output Layer(출력층)에 가까이 있는 Layer들.

# %% [markdown]
# - ### Hyperbolic tangent
# ![image.png](attachment:image.png)
#
#     - $$\large  tanh(z) = \cfrac{e^{z} - e^{-z}}{{e^{z} + e^{-z}}}$$
#     - 출력값의 범위
#         - $-1<tanh(z)<1$
#     - Output이 0을 중심으로 분포하므로 sigmoid보다 학습에 효율 적이다.
#     - 기울기 소실(Gradient Vanishing) 문제를 발생시킨다.

# %% [markdown]
# - ### ReLU(Rectified Linear Unit)
# ![image-2.png](attachment:image-2.png)
#     $$\large  ReLU(z)=max(0,z)$$
#     - 기울기 소실(Gradient Vanishing) 문제를 어느정도 해결
#     - 0이하의 값(z <= 0)들에 대해 뉴런이 죽는 단점이 있다. (Dying ReLU)

# %% [markdown]
# - ### Leaky ReLU
#     ![image-4.png](attachment:image-4.png)
#     <br><br>
#      $$\large  LeakyReLU(z)=max(\alpha z,z)\\
#      0< \alpha <1$$
#     <br><br>
#     - ReLU의 Dying ReLU 현상을 해결하기 위해 나온 함수
#     - 음수 z를 0으로 반환하지 않고 alpah (0 ~ 1 사이 실수)를 곱해 반환한다.

# %% [markdown]
# - ### Softmax
#     $$\large  Softmax(z_j) = \frac{exp(z_j)}{\sum_{k=1}^K exp(z_k)}\\ \:j=1,2, \ldots, K$$
#     - **Multi-class classification(다중 분류)를 위한 네트워크의 Output layer(출력층)의 활성함수로 주로 사용된다.**
#         - 은닉층의 활성함수로 사용하지 않는다.
#     - Layer의 unit들의 출력 값들을 정규화 하여 각 class에 대한 확률값으로 변환한다.
#         - 출력노드들의 값은 0 ~ 1사이의 실수로 변환되고 그 값들의 총합은 1이 된다.
#
#
#
# - **API**
#     - https://keras.io/api/layers/activations/
#     - https://www.tensorflow.org/api_docs/python/tf/keras/activations

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 손실함수(Loss function, 비용함수)
# - Model이 출력한 예측값(prediction) $\hat y^{(i)}$와 실제 데이터(output) $y^{(i)}$의 차이를 계산하는 함수
# - 네트워크 모델을 훈련하는 동안 Loss 함수가 계산한 Loss값(손실)이 최소화 되도록 파라미터(가중치와 편향)을 업데이트한다.
#     - 즉 Loss함수는 최적화 시작이 되는 값이다.
# - 네트워크 모델이 해결하려는 문제의 종류에 따라 다른 Loss함수를 사용한다.
#
# - <font size="5" color="red">해결하려는 문제의 종류에 따라 표준적인 Loss function이 있다.</font>

# %% [markdown]
# - ## Classification (분류)
#     - cross entropy (log loss) 사용
# $$
# \large log(모델이\,출력한\,정답에\,대한\,확률)
# $$

# %% [markdown]
# - ### Binary classification (이진 분류)
#     - 두 개의 클래스를 분류
#         - 모델이 양성(1)의 확률을 출력하여 Threshold 보다 작으면 0, 크면 1로 label을 예측
#     - 예) 문장을 입력하여 긍정/부정 구분
#     - Output Layer의 unit 개수를 1로 하고 activation 함수로 sigmoid를 사용하여 positive(1)의 확률로 예측 결과를 출력하도록 모델을 정의 한 경우 **binary_crossentropy**를 loss function으로 사용한다.
#
#     - $$\large Loss(\hat y^{(i)} ,y^{(i)}) = - y^{(i)} log(\hat y^{(i)} ) - (1- y^{(i)}) log (1-\hat y^{(i)} )$$
#
#     $y^{(i)}$: 실제 값(Ground Truth), $\hat y^{(i)}$: 예측확률

# %% [markdown]
# - ### Multi-class classification (다중 클래스 분류)
#     - 두 개 이상의 클래스를 분류
#         - 여러개 중 하나
#     - 예) 이미지를 0,1,2,...,9로 구분
#     - **categorical_crossentropy**를 loss function으로 사용
#     - $$\large Loss(\hat y_c^{(i)} ,y^{(i)}) = - \sum_{c=1}^C y_c^{(i)} log(\hat y_c^{(i)} ) $$
#
#     $y^{(i)}$: 실제 값(Ground Truth), $\hat y_c^{(i)}$: class별 예측확률

# %% [markdown]
# - ### Regression (회귀)
#     - 연속형 값을 예측
#     - 예) 주가 예측
#     - **Mean squared error**를 loss function으로 사용
#         - "mse" 로 지정
#     - $$\large Loss(\hat y^{(i)} ,y^{(i)}) = \frac  1 2 (\hat y^{(i)} - y^{(i)})^2$$
#
#     $y^{(i)}$: 실제 값(Ground Truth), $\hat y^{(i)}$: 예측 값

# %% [markdown]
# - **API**
#     - https://keras.io/api/losses/
#     - https://www.tensorflow.org/api_docs/python/tf/keras/losses

# %% [markdown]
# ## 평가지표 (Metrics)
# - 모델의 성능을 평가하는 지표
# - 손실함수(Loss Function)와 차이
#     - 손실함수는 모델을 학습할 때 가중치 업데이트를 위한 오차를 구할 때 사용한다.
#     - 평가지표 함수는 모델의 성능이 확인하는데 사용한다.
#
# - **API**
#     - https://keras.io/api/metrics/
#     - https://www.tensorflow.org/api_docs/python/tf/keras/metrics

# %% [markdown]
# ## 문제별 출력레이어 Activation 함수, Loss 함수
#
# 문제형태|Activation함수|Loss 함수
#  :- | :- | :-
# 이진분류(Binary Classification)|sigmoid| binary_crossentropy
# 다중분류(Multi-class Classification)|softmax| categorical_crossentropy<br>sparse_categorical_crossentropy
# 회귀(Regression)|None|MSE

# %% [markdown]
# # Optimizer (최적화 방법)
#
# - Training시 모델 네트워크의 parameter를 데이터에 맞춰 최적화 하는 알고리즘
#     - Deep Learning은 경사하강법(Gradient Descent)와 오차 역전파(back propagation) 알고리즘을 기반으로 파라미터들을 최적화한다.

# %% [markdown]
# ## Gradient Decent (경사하강법)
# - ### 최적화
#     - 모델 네트워크가 출력한 결과와 실제값(Ground Truth)의 차이를 정의하는 함수를 **Loss function(손실함수, 비용함수)** 라고 한다.
#     - Training 시 Loss function이 출력하는 값을 줄이기 위해 파라미터(weight, bias)를 update 과정을 **최적화(Optimization)** 이라고 한다.
# - ### Gradient Decent(경사하강법)
#     - 최적화를 위해 파라미터들에 대한 Loss function의 Gradient값을 구해 Gradient의 반대 방향으로 일정크기 만큼 파라미터들을 업데이트 하는 것을 경사하강법이라고 한다.
#
# $$\large W_{new} = W-\alpha\frac{\partial}{\partial {W}}Loss(W)\\W: 파라미터\: \alpha:학습률$$

# %% [markdown]
# ## 오차 역전파(Back Propagation)
#
# - 딥러닝 학습시 파라미터를 최적화 할 때 추론한 역방향으로 loss를 전달하여 단계적으로 파라미터들을 업데이트한다.
#     - Loss에서부터(뒤에서부터) 한계단씩 미분해 gradient 값을 구하고 이를 Chain rule(연쇄법칙)에 의해 곱해가면서 파라미터를 최적화한다.
#     - 출력에서 입력방향으로 계산하여 역전파(Back propagation)라고 한다.
#         - 추론의 경우 입력에서 출력 방향으로 계산하며 이것은 순전파(Forward propagation)이라고 한다.

# %% [markdown]
# ### 계산 그래프 (Computational Graph)
# - 복잡한 계산 과정을 자료구조의 하나인 그래프로 표현한 것
#     - 딥러닝 모델이 구현된 방식
# - 그래프는 노드(Node)와 엣지(Edge)로 구성됨.
#     - 노드: 연산을 정의
#     - 엣지: 데이터가 흘러가는 방향

# %% [markdown]
# ### 계산 그래프의 예
# - 슈퍼에서 1개에 100원인 사과를 2개 샀을 때 지불할 금액은 어떻게 될까? 단 부가세는 10% 부과된다.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 계산 그래프 절차 및 특장점
# - 계산 그래프를 사용한 문제 풀이 절차
#     - 계산 그래프를 구성
#     - 계산 방향을 결정
#         - 계산 시작에서 계산 결과 방향으로 순서대로 계산: **순전파(Forward propagation)**
#         - 계산 결과에서 계산 시작 역방향으로 계산: **역전파(Back propagation)**
# - 특징/장점
#     - **국소적 계산**을 통해 결과를 얻는다.
#         - 각 노드의 계산은 자신과 관계된 정보(입력 값들)만 가지고 계산한 뒤 그 결과를 다음으로 출력한다.
#     - 복잡한 계산을 단계적으로 나눠 처리하므로 문제를 단순하게 만들어 계산할 수 있다.
#         - **딥러닝에서 역전파를 이용해 각 가중치 업데이트를 위한 미분(기울기) 계산을 효율적으로 할 수 있게 된다.**
#     - 중간 계산결과를 보관할 수 있다.

# %% [markdown]
# ## 합성함수의 미분
# - **<font size='5'>합성함수 : 여러 함수로 구성된 함수</font>**
# $$
# \large z = (x+y)^2\\
# \large z = t^2\\
# \large t=x+y
# $$

# %% [markdown]
# - **<font size='5'>연쇄 법칙(Chain Rule)</font>**
#     - 합성함수의 미분은 합성함수를 구성하는 각 함수의 미분의 곱으로 나타낼 수 있다.
# $$
# \large\cfrac{\partial z}{\partial x} = \cfrac{\partial z}{\partial t} \cfrac{\partial t}{\partial x} \\
# \cfrac{\partial z}{\partial t} = 2t,\;\cfrac{\partial t}{\partial x} = 1 \\
# \large\cfrac{\partial z}{\partial x}=2t \times 1 = 2(x+y)
# $$

# %% [markdown]
# ### 연쇄 법칙과 계산 그래프

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 딥러닝 네트워크에서 최적화 예

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - ### $W_{11}$을 업데이트 하기 위한 미분값은?
# $$
# \large\frac{\partial}{\partial {W_{11}}}{Loss} = ????
# $$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - **순전파(forward propagation): 추론**
# - **역전파(back propagation): 학습시 파라미터(weight) 업데이트**

# %% [markdown]
# ## 파라미터 업데이트 단위
#
# - **Batch Gradient Decent (배치 경사하강법)**
#     - Loss를 계산할 때 전체 학습데이터를 사용해 그 평균값을 기반으로 파라미터를 최적화한다.
#     - 많은 계산량이 필요해서 속도가 느리다. 학습 데이터가 클 경우 메모리가 부족할 수 있다.
#
# - **(mini-batch)Stochastic Gradient Decent (미니배치 확률적 경사하강법)**
#     - Loss를 계산할 때 전체 데이터를 다 사용하지 않고 지정한 데이터 양(batch size) 만큼 마다 계산해 파라미터를 업데이트 한다.
#     - 계산은 빠른 장점이 있지만 최적값을 찾아 가는 방향이 불안정 하여 부정확 하다. 그러나 반복 횟수를 늘리면 Batch 방식과 유사한 결과로 수렴한다.
#
# > **스텝(Step)**:  한번 파라미터를 업데이트하는 단위

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## SGD를 기반으로 한 주요 옵티마이저
# - 방향성을 개선한 최적화 방법
#     - Momentum
#     - NAG(Nesterov Accelerated Gradient)
# - 학습률을 개선한 최적화 방법
#     - Adagrad
#     - RMSProp
# - 방향성 + 학습률 개선 최적화 방법
#     - Adam

# %% [markdown]
# ![image.png](attachment:image.png)
# <center>[출처] https://www.slideshare.net/yongho/ss-79607172</center>
#
# - **API**
#     - https://keras.io/api/optimizers/
#     - https://www.tensorflow.org/api_docs/python/tf/keras/activations

# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(0)

def func(x):
  return 3*x**2 + 2 + np.random.rand(*x.shape)*3

X = np.random.randn(100, 1) #(개수, )
y = func(X)

plt.scatter(X, y)
plt.show()

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
from keras.optimizers.optimizer_v1 import Optimizer
# activation 함수를 사용하지 않는 몯ㄹ

model1 = keras.Sequential()
model1.add(layers.InputLayer(input_shape=(1, )))
model1.add(layers.Dense(10))
model1.add(layers.Dense(1))
model1.compile(optimizer='adam', loss='mse')
model1.fit(X, y, epochs=200)

# %%
X_new=np.linspace(-2,2,1000).reshape(1000,1)
pred_y = model1.predict(X_new)

plt.scatter(X, y)
plt.plot(X_new, pred_y, color='r')
plt.show()
# Out:
# 32/32 [==============================] - 0s 5ms/step

# %%
model2 = keras.Sequential([
    layers.Dense(10, input_shape =(1, )),  # input shape은 첫번째 Layer에 설정할 수 있다.
    layers.ReLU(),    # activation 함수(비선형 함수)
    layers.Dense(1)  # output Layer
])

model2.compile(optimizer='adam', loss='mse')
model2.fit(X, y, epochs=200)
# Out:
# Epoch 1/200
# 4/4 [==============================] - 1s 4ms/step - loss: 60.3298
# Epoch 2/200
# 4/4 [==============================] - 0s 4ms/step - loss: 60.0126
# Epoch 3/200
# 4/4 [==============================] - 0s 5ms/step - loss: 59.7068
# Epoch 4/200
# 4/4 [==============================] - 0s 4ms/step - loss: 59.4215
# Epoch 5/200
# 4/4 [==============================] - 0s 4ms/step - loss: 59.1132
# Epoch 6/200
# 4/4 [==============================] - 0s 4ms/step - loss: 58.8149
# Epoch 7/200
# 4/4 [==============================] - 0s 4ms/step - loss: 58.5156
# Epoch 8/200
# 4/4 [==============================] - 0s 4ms/step - loss: 58.1973
# Epoch 9/200
# 4/4 [==============================] - 0s 4ms/step - loss: 57.8685
# Epoch 10/200
# 4/4 [==============================] - 0s 5ms/step - loss: 57.5746
# Epoch 11/200
# 4/4 [==============================] - 0s 4ms/step - loss: 57.2621
# Epoch 12/200
# 4/4 [==============================] - 0s 3ms/step - loss: 56.9445
# Epoch 13/200
# 4/4 [==============================] - 0s 3ms/step - loss: 56.6401
# Epoch 14/200
# 4/4 [==============================] - 0s 4ms/step - loss: 56.3209
# Epoch 15/200
# 4/4 [==============================] - 0s 3ms/step - loss: 56.0013
# Epoch 16/200
# 4/4 [==============================] - 0s 4ms/step - loss: 55.6714
# Epoch 17/200
# 4/4 [==============================] - 0s 4ms/step - loss: 55.3569
# Epoch 18/200
# 4/4 [==============================] - 0s 4ms/step - loss: 55.0465
# Epoch 19/200
# 4/4 [==============================] - 0s 4ms/step - loss: 54.7252
# Epoch 20/200
# 4/4 [==============================] - 0s 4ms/step - loss: 54.3976
# Epoch 21/200
# 4/4 [==============================] - 0s 5ms/step - loss: 54.0716
# Epoch 22/200
# 4/4 [==============================] - 0s 4ms/step - loss: 53.7291
# Epoch 23/200
# 4/4 [==============================] - 0s 4ms/step - loss: 53.4266
# Epoch 24/200
# 4/4 [==============================] - 0s 5ms/step - loss: 53.0792
# Epoch 25/200
# 4/4 [==============================] - 0s 4ms/step - loss: 52.7476
# Epoch 26/200
# 4/4 [==============================] - 0s 4ms/step - loss: 52.4184
# Epoch 27/200
# 4/4 [==============================] - 0s 4ms/step - loss: 52.0867
# Epoch 28/200
# 4/4 [==============================] - 0s 3ms/step - loss: 51.7328
# Epoch 29/200
# 4/4 [==============================] - 0s 3ms/step - loss: 51.3825
# Epoch 30/200
# 4/4 [==============================] - 0s 3ms/step - loss: 51.0172
# Epoch 31/200
# 4/4 [==============================] - 0s 4ms/step - loss: 50.6726
# Epoch 32/200
# 4/4 [==============================] - 0s 4ms/step - loss: 50.3301
# Epoch 33/200
# 4/4 [==============================] - 0s 4ms/step - loss: 49.9804
# Epoch 34/200
# 4/4 [==============================] - 0s 3ms/step - loss: 49.6177
# Epoch 35/200
# 4/4 [==============================] - 0s 4ms/step - loss: 49.2711
# Epoch 36/200
# 4/4 [==============================] - 0s 4ms/step - loss: 48.9192
# Epoch 37/200
# 4/4 [==============================] - 0s 4ms/step - loss: 48.5629
# Epoch 38/200
# 4/4 [==============================] - 0s 4ms/step - loss: 48.2011
# Epoch 39/200
# 4/4 [==============================] - 0s 5ms/step - loss: 47.8401
# Epoch 40/200
# 4/4 [==============================] - 0s 4ms/step - loss: 47.4764
# Epoch 41/200
# 4/4 [==============================] - 0s 3ms/step - loss: 47.1046
# Epoch 42/200
# 4/4 [==============================] - 0s 3ms/step - loss: 46.7538
# Epoch 43/200
# 4/4 [==============================] - 0s 3ms/step - loss: 46.4122
# Epoch 44/200
# 4/4 [==============================] - 0s 3ms/step - loss: 46.0504
# Epoch 45/200
# 4/4 [==============================] - 0s 3ms/step - loss: 45.7079
# Epoch 46/200
# 4/4 [==============================] - 0s 4ms/step - loss: 45.3664
# Epoch 47/200
# 4/4 [==============================] - 0s 3ms/step - loss: 45.0014
# Epoch 48/200
# 4/4 [==============================] - 0s 5ms/step - loss: 44.6559
# Epoch 49/200
# 4/4 [==============================] - 0s 3ms/step - loss: 44.2818
# Epoch 50/200
# 4/4 [==============================] - 0s 4ms/step - loss: 43.8993
# Epoch 51/200
# 4/4 [==============================] - 0s 4ms/step - loss: 43.5137
# Epoch 52/200
# 4/4 [==============================] - 0s 3ms/step - loss: 43.1564
# Epoch 53/200
# 4/4 [==============================] - 0s 3ms/step - loss: 42.7938
# Epoch 54/200
# 4/4 [==============================] - 0s 3ms/step - loss: 42.4077
# Epoch 55/200
# 4/4 [==============================] - 0s 4ms/step - loss: 42.0228
# Epoch 56/200
# 4/4 [==============================] - 0s 4ms/step - loss: 41.6538
# Epoch 57/200
# 4/4 [==============================] - 0s 4ms/step - loss: 41.2823
# Epoch 58/200
# 4/4 [==============================] - 0s 4ms/step - loss: 40.8862
# Epoch 59/200
# 4/4 [==============================] - 0s 4ms/step - loss: 40.5040
# Epoch 60/200
# 4/4 [==============================] - 0s 4ms/step - loss: 40.1214
# Epoch 61/200
# 4/4 [==============================] - 0s 3ms/step - loss: 39.7307
# Epoch 62/200
# 4/4 [==============================] - 0s 3ms/step - loss: 39.3396
# Epoch 63/200
# 4/4 [==============================] - 0s 4ms/step - loss: 38.9231
# Epoch 64/200
# 4/4 [==============================] - 0s 5ms/step - loss: 38.5214
# Epoch 65/200
# 4/4 [==============================] - 0s 4ms/step - loss: 38.1160
# Epoch 66/200
# 4/4 [==============================] - 0s 4ms/step - loss: 37.7215
# Epoch 67/200
# 4/4 [==============================] - 0s 3ms/step - loss: 37.3239
# Epoch 68/200
# 4/4 [==============================] - 0s 3ms/step - loss: 36.9182
# Epoch 69/200
# 4/4 [==============================] - 0s 3ms/step - loss: 36.5278
# Epoch 70/200
# 4/4 [==============================] - 0s 5ms/step - loss: 36.1416
# Epoch 71/200
# 4/4 [==============================] - 0s 4ms/step - loss: 35.7709
# Epoch 72/200
# 4/4 [==============================] - 0s 4ms/step - loss: 35.3629
# Epoch 73/200
# 4/4 [==============================] - 0s 3ms/step - loss: 34.9992
# Epoch 74/200
# 4/4 [==============================] - 0s 3ms/step - loss: 34.5888
# Epoch 75/200
# 4/4 [==============================] - 0s 3ms/step - loss: 34.2169
# Epoch 76/200
# 4/4 [==============================] - 0s 3ms/step - loss: 33.8417
# Epoch 77/200
# 4/4 [==============================] - 0s 3ms/step - loss: 33.4687
# Epoch 78/200
# 4/4 [==============================] - 0s 3ms/step - loss: 33.0815
# Epoch 79/200
# 4/4 [==============================] - 0s 3ms/step - loss: 32.7243
# Epoch 80/200
# 4/4 [==============================] - 0s 4ms/step - loss: 32.3172
# Epoch 81/200
# 4/4 [==============================] - 0s 3ms/step - loss: 31.9619
# Epoch 82/200
# 4/4 [==============================] - 0s 3ms/step - loss: 31.5806
# Epoch 83/200
# 4/4 [==============================] - 0s 3ms/step - loss: 31.2053
# Epoch 84/200
# 4/4 [==============================] - 0s 3ms/step - loss: 30.8329
# Epoch 85/200
# 4/4 [==============================] - 0s 4ms/step - loss: 30.4947
# Epoch 86/200
# 4/4 [==============================] - 0s 4ms/step - loss: 30.1067
# Epoch 87/200
# 4/4 [==============================] - 0s 4ms/step - loss: 29.7412
# Epoch 88/200
# 4/4 [==============================] - 0s 5ms/step - loss: 29.3250
# Epoch 89/200
# 4/4 [==============================] - 0s 4ms/step - loss: 28.9526
# Epoch 90/200
# 4/4 [==============================] - 0s 3ms/step - loss: 28.5577
# Epoch 91/200
# 4/4 [==============================] - 0s 3ms/step - loss: 28.1831
# Epoch 92/200
# 4/4 [==============================] - 0s 3ms/step - loss: 27.8066
# Epoch 93/200
# 4/4 [==============================] - 0s 3ms/step - loss: 27.4590
# Epoch 94/200
# 4/4 [==============================] - 0s 6ms/step - loss: 27.1270
# Epoch 95/200
# 4/4 [==============================] - 0s 3ms/step - loss: 26.8053
# Epoch 96/200
# 4/4 [==============================] - 0s 3ms/step - loss: 26.4684
# Epoch 97/200
# 4/4 [==============================] - 0s 4ms/step - loss: 26.1478
# Epoch 98/200
# 4/4 [==============================] - 0s 3ms/step - loss: 25.8104
# Epoch 99/200
# 4/4 [==============================] - 0s 3ms/step - loss: 25.4993
# Epoch 100/200
# 4/4 [==============================] - 0s 3ms/step - loss: 25.1820
# Epoch 101/200
# 4/4 [==============================] - 0s 4ms/step - loss: 24.8583
# Epoch 102/200
# 4/4 [==============================] - 0s 7ms/step - loss: 24.5077
# Epoch 103/200
# 4/4 [==============================] - 0s 4ms/step - loss: 24.1968
# Epoch 104/200
# 4/4 [==============================] - 0s 5ms/step - loss: 23.8619
# Epoch 105/200
# 4/4 [==============================] - 0s 6ms/step - loss: 23.5539
# Epoch 106/200
# 4/4 [==============================] - 0s 6ms/step - loss: 23.2545
# Epoch 107/200
# 4/4 [==============================] - 0s 5ms/step - loss: 22.9464
# Epoch 108/200
# 4/4 [==============================] - 0s 5ms/step - loss: 22.6450
# Epoch 109/200
# 4/4 [==============================] - 0s 5ms/step - loss: 22.3616
# Epoch 110/200
# 4/4 [==============================] - 0s 5ms/step - loss: 22.0561
# Epoch 111/200
# 4/4 [==============================] - 0s 5ms/step - loss: 21.7531
# Epoch 112/200
# 4/4 [==============================] - 0s 5ms/step - loss: 21.4599
# Epoch 113/200
# 4/4 [==============================] - 0s 5ms/step - loss: 21.1450
# Epoch 114/200
# 4/4 [==============================] - 0s 13ms/step - loss: 20.8094
# Epoch 115/200
# 4/4 [==============================] - 0s 5ms/step - loss: 20.5253
# Epoch 116/200
# 4/4 [==============================] - 0s 4ms/step - loss: 20.2478
# Epoch 117/200
# 4/4 [==============================] - 0s 13ms/step - loss: 19.9746
# Epoch 118/200
# 4/4 [==============================] - 0s 17ms/step - loss: 19.7154
# Epoch 119/200
# 4/4 [==============================] - 0s 8ms/step - loss: 19.4281
# Epoch 120/200
# 4/4 [==============================] - 0s 7ms/step - loss: 19.1796
# Epoch 121/200
# 4/4 [==============================] - 0s 5ms/step - loss: 18.9343
# Epoch 122/200
# 4/4 [==============================] - 0s 5ms/step - loss: 18.6760
# Epoch 123/200
# 4/4 [==============================] - 0s 5ms/step - loss: 18.4262
# Epoch 124/200
# 4/4 [==============================] - 0s 6ms/step - loss: 18.1884
# Epoch 125/200
# 4/4 [==============================] - 0s 5ms/step - loss: 17.9589
# Epoch 126/200
# 4/4 [==============================] - 0s 5ms/step - loss: 17.7134
# Epoch 127/200
# 4/4 [==============================] - 0s 5ms/step - loss: 17.4779
# Epoch 128/200
# 4/4 [==============================] - 0s 14ms/step - loss: 17.2507
# Epoch 129/200
# 4/4 [==============================] - 0s 5ms/step - loss: 17.0178
# Epoch 130/200
# 4/4 [==============================] - 0s 3ms/step - loss: 16.7951
# Epoch 131/200
# 4/4 [==============================] - 0s 4ms/step - loss: 16.5540
# Epoch 132/200
# 4/4 [==============================] - 0s 4ms/step - loss: 16.3379
# Epoch 133/200
# 4/4 [==============================] - 0s 4ms/step - loss: 16.1084
# Epoch 134/200
# 4/4 [==============================] - 0s 3ms/step - loss: 15.8816
# Epoch 135/200
# 4/4 [==============================] - 0s 3ms/step - loss: 15.6731
# Epoch 136/200
# 4/4 [==============================] - 0s 3ms/step - loss: 15.4802
# Epoch 137/200
# 4/4 [==============================] - 0s 4ms/step - loss: 15.2891
# Epoch 138/200
# 4/4 [==============================] - 0s 3ms/step - loss: 15.1082
# Epoch 139/200
# 4/4 [==============================] - 0s 3ms/step - loss: 14.9430
# Epoch 140/200
# 4/4 [==============================] - 0s 3ms/step - loss: 14.7593
# Epoch 141/200
# 4/4 [==============================] - 0s 3ms/step - loss: 14.5902
# Epoch 142/200
# 4/4 [==============================] - 0s 3ms/step - loss: 14.4279
# Epoch 143/200
# 4/4 [==============================] - 0s 3ms/step - loss: 14.2638
# Epoch 144/200
# 4/4 [==============================] - 0s 3ms/step - loss: 14.0873
# Epoch 145/200
# 4/4 [==============================] - 0s 4ms/step - loss: 13.9169
# Epoch 146/200
# 4/4 [==============================] - 0s 4ms/step - loss: 13.7449
# Epoch 147/200
# 4/4 [==============================] - 0s 3ms/step - loss: 13.5758
# Epoch 148/200
# 4/4 [==============================] - 0s 4ms/step - loss: 13.4242
# Epoch 149/200
# 4/4 [==============================] - 0s 4ms/step - loss: 13.2636
# Epoch 150/200
# 4/4 [==============================] - 0s 4ms/step - loss: 13.1194
# Epoch 151/200
# 4/4 [==============================] - 0s 4ms/step - loss: 12.9597
# Epoch 152/200
# 4/4 [==============================] - 0s 3ms/step - loss: 12.8204
# Epoch 153/200
# 4/4 [==============================] - 0s 3ms/step - loss: 12.6786
# Epoch 154/200
# 4/4 [==============================] - 0s 4ms/step - loss: 12.5442
# Epoch 155/200
# 4/4 [==============================] - 0s 4ms/step - loss: 12.4208
# Epoch 156/200
# 4/4 [==============================] - 0s 4ms/step - loss: 12.2823
# Epoch 157/200
# 4/4 [==============================] - 0s 3ms/step - loss: 12.1370
# Epoch 158/200
# 4/4 [==============================] - 0s 4ms/step - loss: 11.9940
# Epoch 159/200
# 4/4 [==============================] - 0s 4ms/step - loss: 11.8528
# Epoch 160/200
# 4/4 [==============================] - 0s 4ms/step - loss: 11.7212
# Epoch 161/200
# 4/4 [==============================] - 0s 4ms/step - loss: 11.5995
# Epoch 162/200
# 4/4 [==============================] - 0s 5ms/step - loss: 11.4862
# Epoch 163/200
# 4/4 [==============================] - 0s 4ms/step - loss: 11.3780
# Epoch 164/200
# 4/4 [==============================] - 0s 5ms/step - loss: 11.2727
# Epoch 165/200
# 4/4 [==============================] - 0s 4ms/step - loss: 11.1546
# Epoch 166/200
# 4/4 [==============================] - 0s 4ms/step - loss: 11.0649
# Epoch 167/200
# 4/4 [==============================] - 0s 4ms/step - loss: 10.9580
# Epoch 168/200
# 4/4 [==============================] - 0s 4ms/step - loss: 10.8563
# Epoch 169/200
# 4/4 [==============================] - 0s 4ms/step - loss: 10.7526
# Epoch 170/200
# 4/4 [==============================] - 0s 5ms/step - loss: 10.6588
# Epoch 171/200
# 4/4 [==============================] - 0s 3ms/step - loss: 10.5530
# Epoch 172/200
# 4/4 [==============================] - 0s 3ms/step - loss: 10.4588
# Epoch 173/200
# 4/4 [==============================] - 0s 4ms/step - loss: 10.3733
# Epoch 174/200
# 4/4 [==============================] - 0s 4ms/step - loss: 10.2495
# Epoch 175/200
# 4/4 [==============================] - 0s 4ms/step - loss: 10.1227
# Epoch 176/200
# 4/4 [==============================] - 0s 4ms/step - loss: 10.0344
# Epoch 177/200
# 4/4 [==============================] - 0s 3ms/step - loss: 9.9170
# Epoch 178/200
# 4/4 [==============================] - 0s 4ms/step - loss: 9.8256
# Epoch 179/200
# 4/4 [==============================] - 0s 3ms/step - loss: 9.7069
# Epoch 180/200
# 4/4 [==============================] - 0s 4ms/step - loss: 9.6258
# Epoch 181/200
# 4/4 [==============================] - 0s 4ms/step - loss: 9.5387
# Epoch 182/200
# 4/4 [==============================] - 0s 4ms/step - loss: 9.4670
# Epoch 183/200
# 4/4 [==============================] - 0s 4ms/step - loss: 9.3872
# Epoch 184/200
# 4/4 [==============================] - 0s 4ms/step - loss: 9.3206
# Epoch 185/200
# 4/4 [==============================] - 0s 4ms/step - loss: 9.2533
# Epoch 186/200
# 4/4 [==============================] - 0s 4ms/step - loss: 9.1842
# Epoch 187/200
# 4/4 [==============================] - 0s 4ms/step - loss: 9.1132
# Epoch 188/200
# 4/4 [==============================] - 0s 4ms/step - loss: 9.0462
# Epoch 189/200
# 4/4 [==============================] - 0s 4ms/step - loss: 8.9615
# Epoch 190/200
# 4/4 [==============================] - 0s 4ms/step - loss: 8.8866
# Epoch 191/200
# 4/4 [==============================] - 0s 4ms/step - loss: 8.8160
# Epoch 192/200
# 4/4 [==============================] - 0s 3ms/step - loss: 8.7481
# Epoch 193/200
# 4/4 [==============================] - 0s 3ms/step - loss: 8.6582
# Epoch 194/200
# 4/4 [==============================] - 0s 4ms/step - loss: 8.5797
# Epoch 195/200
# 4/4 [==============================] - 0s 4ms/step - loss: 8.4870
# Epoch 196/200
# 4/4 [==============================] - 0s 4ms/step - loss: 8.4199
# Epoch 197/200
# 4/4 [==============================] - 0s 4ms/step - loss: 8.3574
# Epoch 198/200
# 4/4 [==============================] - 0s 4ms/step - loss: 8.2849
# Epoch 199/200
# 4/4 [==============================] - 0s 4ms/step - loss: 8.2271
# Epoch 200/200
# 4/4 [==============================] - 0s 3ms/step - loss: 8.1702

# %%
X_new=np.linspace(-2,2,1000).reshape(1000,1)
pred_y = model2.predict(X_new)

plt.scatter(X, y)
plt.plot(X_new, pred_y, color='r')
plt.show()
# Out:
# 32/32 [==============================] - 0s 2ms/step
