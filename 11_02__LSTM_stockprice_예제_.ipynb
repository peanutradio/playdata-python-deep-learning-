# %% [markdown]
# - Yahoo Finance 에서 주가 데이터 다운로드 (https://finance.yahoo.com/)
# - 검색 후 Historical Data 선택
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# - 기간 선택 후 Apply -> Download 클릭
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### Data Loading 및 확인

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/samsung_stock_price.csv')
df.shape
# Out:
# (5814, 7)

# %%
df.head()
# Out:
#          Date    Open    High     Low   Close    Adj Close    Volume
# 0  2000-01-04  6000.0  6110.0  5660.0  6110.0  4563.384766  74195000
# 1  2000-01-05  5800.0  6060.0  5520.0  5580.0  4167.542480  74680000
# 2  2000-01-06  5750.0  5780.0  5580.0  5620.0  4197.417969  54390000
# 3  2000-01-07  5560.0  5670.0  5360.0  5540.0  4137.667969  40305000
# 4  2000-01-10  5600.0  5770.0  5580.0  5770.0  4309.446777  46880000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5814 entries, 0 to 5813
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       5814 non-null   object
#  1   Open       5814 non-null   float64
#  2   High       5814 non-null   float64
#  3   Low        5814 non-null   float64
#  4   Close      5814 non-null   float64
#  5   Adj Close  5814 non-null   float64
#  6   Volume     5814 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 318.1+ KB

# %%
#Date 컬럼을 index로 변환
df['Date'] = pd.to_datetime(df['Date'])  # Datetime 타입으로 변환
df.set_index('Date', inplace=True)

# %%
df.head()
# Out:
#               Open    High     Low   Close    Adj Close    Volume
# Date
# 2000-01-04  6000.0  6110.0  5660.0  6110.0  4563.384766  74195000
# 2000-01-05  5800.0  6060.0  5520.0  5580.0  4167.542480  74680000
# 2000-01-06  5750.0  5780.0  5580.0  5620.0  4197.417969  54390000
# 2000-01-07  5560.0  5670.0  5360.0  5540.0  4137.667969  40305000
# 2000-01-10  5600.0  5770.0  5580.0  5770.0  4309.446777  46880000

# %%
df[['Open', 'Close']].plot(figsize=(20,5), alpha=0.5)
# Out:
# <Axes: xlabel='Date'>

# %%
df[['Open', 'Close']].iloc[:50].plot(figsize=(20, 5), marker='*');

# %% [markdown]
# ##### 전처리
# - date를 index
# - 결측치 제거
# - Adj Close 컬럼 제거
# - MinMaxScaling

# %%
df.drop(columns=['Adj Close'], inplace=True)

# %%
df.head()
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2000-01-04  6000.0  6110.0  5660.0  6110.0  74195000
# 2000-01-05  5800.0  6060.0  5520.0  5580.0  74680000
# 2000-01-06  5750.0  5780.0  5580.0  5620.0  54390000
# 2000-01-07  5560.0  5670.0  5360.0  5540.0  40305000
# 2000-01-10  5600.0  5770.0  5580.0  5770.0  46880000

# %% [markdown]
# ### X, y 분리

# %%
df_y = df['Close'].to_frame()  #Series.to_frame(): Series를 DataFrame으로 변환. ==> 2차원 배열형태로 만들기 위해서.
df_x = df

# %% [markdown]
# ### Scaling - MinMaxScaler
# - Scaler를 X, y 용 따로 만든다.
#     - y를 inverse 하기 위해

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
y_scaler = MinMaxScaler()
X = scaler.fit_transform(df_x)
# y = df_y.values
y = y_scaler.fit_transform(df_y)

# %%
X.shape, y.shape
# Out:
# ((5814, 5), (5814, 1))

# %%
y.max(), y.min()
# Out:
# (1.0, 0.0)

# %% [markdown]
# ##  날짜 종가 예측
# - X: 50일치 주가(ex:1일 ~ 50일), y: 51일째 주가. (ex: 51일)
#     - 50일의 연속된 주식가격을 할습하여 51일째 주가를 예측한다.
#     - X의 한개의 데이터가 50일치 주가가 된다.
# <br>
#
# ![image-2.png](attachment:image-2.png)
# <center>[연속된 날짜가 5인 경우]</center>

# %% [markdown]
# X, y를 만든다.
# 각 index에 window size의 데이터셋이 들어가도록 한다.

# %% [markdown]
# ##### input sequence dataset 만들기

# %%
X.shape, y.shape, y.size
# Out:
# ((5814, 5), (5814, 1), 5814)

# %%
window_size = 50  # 50일치를 sequence로 묶는다.
data_x = [] # input data들을 저장할 리스트
data_y = [] # output data를 저장할 리스트

for i in range(0, y.size - window_size):# window size + 1개 남을때까지 돌게하기 위해.
    _X = X[i:i+window_size]  # 0 ~ 49, 1 ~50..
    _y = y[i+window_size]    # 50    , 51 ...
    data_x.append(_X)
    data_y.append(_y)

# %%
np.shape(data_x)
# Out:
# (5764, 50, 5)

# %%
np.shape(data_y)
# Out:
# (5764, 1)

# %%
data_x[0]
# Out:
# array([[0.03942571, 0.03562314, 0.03720717, 0.03829161, 0.45181622],
#        [0.03714676, 0.03509145, 0.03559945, 0.0322873 , 0.45476966],
#        [0.03657703, 0.03211399, 0.03628847, 0.03274046, 0.33121213],
#        [0.03441203, 0.03094428, 0.03376206, 0.03183415, 0.24544043],
#        [0.03486782, 0.03200766, 0.03628847, 0.03443979, 0.2854794 ],
#        [0.03737466, 0.0355168 , 0.03847037, 0.03443979, 0.36382182],
#        [0.03498177, 0.03168864, 0.03651814, 0.03387334, 0.17793746],
#        [0.03486782, 0.03168864, 0.0360588 , 0.03376005, 0.2508297 ],
#        [0.03623519, 0.03317737, 0.03743684, 0.03511952, 0.3006729 ],
#        [0.03942571, 0.0363675 , 0.04019293, 0.03817832, 0.38671863],
#        [0.04124886, 0.03615483, 0.04088195, 0.03817832, 0.27561429],
#        [0.03942571, 0.03487877, 0.04065227, 0.03659227, 0.24483147],
#        [0.03783045, 0.03487877, 0.03904456, 0.03749858, 0.22723259],
#        [0.03885597, 0.03424075, 0.03973358, 0.03568596, 0.19812441],
#        [0.03714676, 0.03339005, 0.03766651, 0.03364677, 0.20920744],
#        [0.03395624, 0.03062527, 0.03468075, 0.03070126, 0.26946381],
#        [0.03372835, 0.02934921, 0.03433624, 0.03115441, 0.17833328],
#        [0.03350046, 0.03041259, 0.03456592, 0.03160757, 0.16989922],
#        [0.03532361, 0.03317737, 0.03582912, 0.03500623, 0.23332217],
#        [0.03532361, 0.03158231, 0.0360588 , 0.0322873 , 0.24132996],
#        [0.03486782, 0.03105062, 0.03261369, 0.02934179, 0.43522212],
#        [0.03053783, 0.02775415, 0.03089113, 0.02854877, 0.39037238],
#        [0.03087967, 0.02871119, 0.02928342, 0.02718931, 0.86937856],
#        [0.02951231, 0.02520204, 0.03112081, 0.02718931, 0.        ],
#        [0.02962625, 0.0273288 , 0.03008728, 0.02843548, 0.39058551],
#        [0.0319052 , 0.02892386, 0.03318787, 0.03058797, 0.35599671],
#        [0.03441203, 0.03147597, 0.0351401 , 0.03387334, 0.31087294],
#        [0.0355515 , 0.03317737, 0.03651814, 0.0343265 , 0.37660993],
#        [0.03896992, 0.03402807, 0.03743684, 0.03364677, 0.21106476],
#        [0.03486782, 0.03083794, 0.03353238, 0.03002152, 0.26879396],
#        [0.03236098, 0.02828584, 0.03123565, 0.02798233, 0.23332217],
#        [0.03008204, 0.02594641, 0.02710152, 0.02571655, 0.44523947],
#        [0.02734731, 0.02488303, 0.0285944 , 0.02662286, 0.39694912],
#        [0.03224704, 0.03051893, 0.03146532, 0.02911521, 0.66224157],
#        [0.03030994, 0.02658443, 0.02997244, 0.02650957, 0.16128247],
#        [0.02803099, 0.02637176, 0.02962793, 0.02707602, 0.14724599],
#        [0.03053783, 0.02658443, 0.0307763 , 0.02730259, 0.16880309],
#        [0.02939836, 0.02637176, 0.03031695, 0.02650957, 0.15878574],
#        [0.02894257, 0.02541472, 0.02939825, 0.02707602, 0.16974698],
#        [0.02803099, 0.02435134, 0.02733119, 0.02345078, 0.18353987],
#        [0.02689152, 0.02530838, 0.02779054, 0.02707602, 0.31556192],
#        [0.02939836, 0.0250957 , 0.03100597, 0.02707602, 0.        ],
#        [0.03805834, 0.03317737, 0.03559945, 0.03568596, 0.71704777],
#        [0.04170465, 0.03711187, 0.03973358, 0.03704543, 0.85856956],
#        [0.03942571, 0.03498511, 0.03651814, 0.03296703, 0.23840697],
#        [0.03486782, 0.03062527, 0.0351401 , 0.03274046, 0.1831136 ],
#        [0.03395624, 0.03445342, 0.03536977, 0.03613912, 0.19766769],
#        [0.03908387, 0.03424075, 0.03674782, 0.03274046, 0.3403465 ],
#        [0.03703282, 0.03232667, 0.03559945, 0.03183415, 0.17419237],
#        [0.03350046, 0.0290302 , 0.03146532, 0.02775575, 0.19617575]])

# %%
y[0]
# Out:
# array([0.03829161])

# %% [markdown]
# ## Train, Test 분리
# - Train : 8, Test: 2의 비율로 나눈다.

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(data_x, data_y, test_size=0.2, random_state=0)

# %%
X_train = np.array(X_train)
X_test = np.array(X_test)
y_train = np.array(y_train)
y_test = np.array(y_test)

type(X_train)
# Out:
# numpy.ndarray

# %% [markdown]
# ##### import

# %%
import tensorflow as tf
from tensorflow import keras 
from tensorflow.keras import layers

# %% [markdown]
# ##### 하이퍼파라미터 정의

# %%
LEARNING_RATE = 0.001
N_EPOCH = 100
N_BATCH = 1000

# %% [markdown]
# ##### Dataset 생성

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train))\
                       .shuffle(X_train.shape[0]).batch(N_BATCH, drop_remainder=True)
test_dataset = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(N_BATCH)

# %% [markdown]
# ## Model 생성

# %% [markdown]
# - LSTM 레이어는 return_sequences 인자에 따라 마지막 시퀀스에서 한 번만 출력할 수 있고 각 시퀀스에서 출력을 할 수 있다.
#     - return_sequences=True: 시퀀스마다 결과를 출력. False(기본값): 전체 Sequence를 처리하고 결과를 하나만 출력
# - many to many 문제를 풀거나 LSTM 레이어를 여러개로 쌓아올릴 때는 return_sequence=True 옵션을 사용.
# - Fully Connected Layer(Dense)와 연결된 경우 return_sequence=False로 해서 하나만 전달.
# - 아래 그림에서 왼쪽은 return_sequences=False일 때, 오른쪽은 return_sequence=True일 때의 형상.
#
# ![image.png](attachment:image.png)
#
# <center>[출처: https://tykimos.github.io/2017/04/09/RNN_Getting_Started]</center>

# %%
X_train.shape
# Out:
# (4611, 50, 5)

# %% [markdown]
# ##### 모델 생성, 컴파일

# %%
def get_model():
    model = keras.Sequential()
    model.add(layers.InputLayer(input_shape=(window_size, 5)))
    model.add(layers.LSTM(32, return_sequences=False, activation='tanh'))
    model.add(layers.Dense(32, activation='relu'))
    model.add(layers.Dense(1))
    
    model.compile(optimizer=keras.optimizers.Adam(LEARNING_RATE), loss='mse')
    
    return model

# %%
model = get_model()
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 32)                4864
#
#  dense_2 (Dense)             (None, 32)                1056
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,953
# Trainable params: 5,953
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ##### 모델 학습, 평가

# %%
hist = model.fit(train_dataset, epochs=N_EPOCH, validation_data=test_dataset)
# Out:
# Epoch 1/100
# 4/4 [==============================] - 3s 260ms/step - loss: 0.0659 - val_loss: 0.0243
# Epoch 2/100
# 4/4 [==============================] - 0s 106ms/step - loss: 0.0129 - val_loss: 0.0029
# Epoch 3/100
# 4/4 [==============================] - 0s 105ms/step - loss: 0.0059 - val_loss: 0.0110
# Epoch 4/100
# 4/4 [==============================] - 0s 103ms/step - loss: 0.0098 - val_loss: 0.0060
# Epoch 5/100
# 4/4 [==============================] - 0s 99ms/step - loss: 0.0036 - val_loss: 0.0015
# Epoch 6/100
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0018 - val_loss: 0.0025
# Epoch 7/100
# 4/4 [==============================] - 0s 105ms/step - loss: 0.0028 - val_loss: 0.0023
# Epoch 8/100
# 4/4 [==============================] - 0s 104ms/step - loss: 0.0018 - val_loss: 9.3548e-04
# Epoch 9/100
# 4/4 [==============================] - 0s 129ms/step - loss: 7.6351e-04 - val_loss: 7.7755e-04
# Epoch 10/100
# 4/4 [==============================] - 1s 171ms/step - loss: 8.7830e-04 - val_loss: 9.7218e-04
# Epoch 11/100
# 4/4 [==============================] - 0s 104ms/step - loss: 8.4077e-04 - val_loss: 5.7444e-04
# Epoch 12/100
# 4/4 [==============================] - 0s 99ms/step - loss: 4.5136e-04 - val_loss: 3.7188e-04
# Epoch 13/100
# 4/4 [==============================] - 0s 114ms/step - loss: 3.9996e-04 - val_loss: 4.2768e-04
# Epoch 14/100
# 4/4 [==============================] - 1s 125ms/step - loss: 4.1573e-04 - val_loss: 3.3626e-04
# Epoch 15/100
# 4/4 [==============================] - 1s 121ms/step - loss: 2.9261e-04 - val_loss: 2.5527e-04
# Epoch 16/100
# 4/4 [==============================] - 0s 112ms/step - loss: 2.6520e-04 - val_loss: 2.6121e-04
# Epoch 17/100
# 4/4 [==============================] - 0s 104ms/step - loss: 2.4161e-04 - val_loss: 2.2817e-04
# Epoch 18/100
# 4/4 [==============================] - 0s 115ms/step - loss: 2.2005e-04 - val_loss: 2.1013e-04
# Epoch 19/100
# 4/4 [==============================] - 0s 104ms/step - loss: 2.1565e-04 - val_loss: 2.0541e-04
# Epoch 20/100
# 4/4 [==============================] - 0s 111ms/step - loss: 2.0344e-04 - val_loss: 1.8883e-04
# Epoch 21/100
# 4/4 [==============================] - 0s 120ms/step - loss: 1.9430e-04 - val_loss: 1.8360e-04
# Epoch 22/100
# 4/4 [==============================] - 0s 106ms/step - loss: 1.8953e-04 - val_loss: 1.7556e-04
# Epoch 23/100
# 4/4 [==============================] - 0s 107ms/step - loss: 1.6684e-04 - val_loss: 1.7213e-04
# Epoch 24/100
# 4/4 [==============================] - 0s 108ms/step - loss: 1.6728e-04 - val_loss: 1.6820e-04
# Epoch 25/100
# 4/4 [==============================] - 0s 103ms/step - loss: 1.7064e-04 - val_loss: 1.6155e-04
# Epoch 26/100
# 4/4 [==============================] - 0s 102ms/step - loss: 1.6537e-04 - val_loss: 1.5832e-04
# Epoch 27/100
# 4/4 [==============================] - 0s 106ms/step - loss: 1.5643e-04 - val_loss: 1.5463e-04
# Epoch 28/100
# 4/4 [==============================] - 0s 106ms/step - loss: 1.5946e-04 - val_loss: 1.5310e-04
# Epoch 29/100
# 4/4 [==============================] - 0s 119ms/step - loss: 1.5485e-04 - val_loss: 1.4945e-04
# Epoch 30/100
# 4/4 [==============================] - 0s 117ms/step - loss: 1.4322e-04 - val_loss: 1.4730e-04
# Epoch 31/100
# 4/4 [==============================] - 0s 103ms/step - loss: 1.5345e-04 - val_loss: 1.4568e-04
# Epoch 32/100
# 4/4 [==============================] - 0s 124ms/step - loss: 1.4918e-04 - val_loss: 1.4391e-04
# Epoch 33/100
# 4/4 [==============================] - 0s 105ms/step - loss: 1.4564e-04 - val_loss: 1.4246e-04
# Epoch 34/100
# 4/4 [==============================] - 1s 116ms/step - loss: 1.4472e-04 - val_loss: 1.4045e-04
# Epoch 35/100
# 4/4 [==============================] - 0s 114ms/step - loss: 1.3756e-04 - val_loss: 1.3914e-04
# Epoch 36/100
# 4/4 [==============================] - 0s 113ms/step - loss: 1.4380e-04 - val_loss: 1.3749e-04
# Epoch 37/100
# 4/4 [==============================] - 0s 105ms/step - loss: 1.4241e-04 - val_loss: 1.3558e-04
# Epoch 38/100
# 4/4 [==============================] - 0s 110ms/step - loss: 1.3516e-04 - val_loss: 1.3387e-04
# Epoch 39/100
# 4/4 [==============================] - 0s 105ms/step - loss: 1.3470e-04 - val_loss: 1.3277e-04
# Epoch 40/100
# 4/4 [==============================] - 1s 133ms/step - loss: 1.2895e-04 - val_loss: 1.2926e-04
# Epoch 41/100
# 4/4 [==============================] - 1s 151ms/step - loss: 1.2990e-04 - val_loss: 1.2688e-04
# Epoch 42/100
# 4/4 [==============================] - 1s 138ms/step - loss: 1.2753e-04 - val_loss: 1.2542e-04
# Epoch 43/100
# 4/4 [==============================] - 1s 143ms/step - loss: 1.2658e-04 - val_loss: 1.2359e-04
# Epoch 44/100
# 4/4 [==============================] - 1s 150ms/step - loss: 1.2775e-04 - val_loss: 1.2444e-04
# Epoch 45/100
# 4/4 [==============================] - 1s 133ms/step - loss: 1.2716e-04 - val_loss: 1.2168e-04
# Epoch 46/100
# 4/4 [==============================] - 1s 131ms/step - loss: 1.2777e-04 - val_loss: 1.2074e-04
# Epoch 47/100
# 4/4 [==============================] - 1s 195ms/step - loss: 1.1846e-04 - val_loss: 1.2255e-04
# Epoch 48/100
# 4/4 [==============================] - 1s 228ms/step - loss: 1.2340e-04 - val_loss: 1.1933e-04
# Epoch 49/100
# 4/4 [==============================] - 1s 203ms/step - loss: 1.2041e-04 - val_loss: 1.1938e-04
# Epoch 50/100
# 4/4 [==============================] - 1s 233ms/step - loss: 1.2072e-04 - val_loss: 1.1896e-04
# Epoch 51/100
# 4/4 [==============================] - 1s 236ms/step - loss: 1.2136e-04 - val_loss: 1.1703e-04
# Epoch 52/100
# 4/4 [==============================] - 1s 243ms/step - loss: 1.1724e-04 - val_loss: 1.1857e-04
# Epoch 53/100
# 4/4 [==============================] - 1s 217ms/step - loss: 1.1581e-04 - val_loss: 1.1607e-04
# Epoch 54/100
# 4/4 [==============================] - 1s 193ms/step - loss: 1.1763e-04 - val_loss: 1.1568e-04
# Epoch 55/100
# 4/4 [==============================] - 1s 144ms/step - loss: 1.1770e-04 - val_loss: 1.1581e-04
# Epoch 56/100
# 4/4 [==============================] - 1s 124ms/step - loss: 1.1562e-04 - val_loss: 1.1479e-04
# Epoch 57/100
# 4/4 [==============================] - 1s 132ms/step - loss: 1.1591e-04 - val_loss: 1.1359e-04
# Epoch 58/100
# 4/4 [==============================] - 1s 156ms/step - loss: 1.1087e-04 - val_loss: 1.1412e-04
# Epoch 59/100
# 4/4 [==============================] - 1s 126ms/step - loss: 1.1756e-04 - val_loss: 1.1250e-04
# Epoch 60/100
# 4/4 [==============================] - 0s 125ms/step - loss: 1.1160e-04 - val_loss: 1.1248e-04
# Epoch 61/100
# 4/4 [==============================] - 0s 122ms/step - loss: 1.1253e-04 - val_loss: 1.1214e-04
# Epoch 62/100
# 4/4 [==============================] - 1s 126ms/step - loss: 1.1437e-04 - val_loss: 1.1096e-04
# Epoch 63/100
# 4/4 [==============================] - 0s 123ms/step - loss: 1.0976e-04 - val_loss: 1.1147e-04
# Epoch 64/100
# 4/4 [==============================] - 0s 124ms/step - loss: 1.1076e-04 - val_loss: 1.1047e-04
# Epoch 65/100
# 4/4 [==============================] - 0s 127ms/step - loss: 1.0966e-04 - val_loss: 1.1001e-04
# Epoch 66/100
# 4/4 [==============================] - 1s 128ms/step - loss: 1.1301e-04 - val_loss: 1.0977e-04
# Epoch 67/100
# 4/4 [==============================] - 0s 123ms/step - loss: 1.1256e-04 - val_loss: 1.0863e-04
# Epoch 68/100
# 4/4 [==============================] - 0s 123ms/step - loss: 1.1158e-04 - val_loss: 1.0888e-04
# Epoch 69/100
# 4/4 [==============================] - 1s 122ms/step - loss: 1.0665e-04 - val_loss: 1.0903e-04
# Epoch 70/100
# 4/4 [==============================] - 0s 123ms/step - loss: 1.0876e-04 - val_loss: 1.0716e-04
# Epoch 71/100
# 4/4 [==============================] - 0s 122ms/step - loss: 1.0640e-04 - val_loss: 1.0836e-04
# Epoch 72/100
# 4/4 [==============================] - 0s 121ms/step - loss: 1.1283e-04 - val_loss: 1.0629e-04
# Epoch 73/100
# 4/4 [==============================] - 0s 122ms/step - loss: 1.0614e-04 - val_loss: 1.0838e-04
# Epoch 74/100
# 4/4 [==============================] - 1s 128ms/step - loss: 1.0676e-04 - val_loss: 1.0535e-04
# Epoch 75/100
# 4/4 [==============================] - 0s 119ms/step - loss: 1.0776e-04 - val_loss: 1.0526e-04
# Epoch 76/100
# 4/4 [==============================] - 0s 118ms/step - loss: 1.1022e-04 - val_loss: 1.0588e-04
# Epoch 77/100
# 4/4 [==============================] - 0s 123ms/step - loss: 1.0930e-04 - val_loss: 1.0408e-04
# Epoch 78/100
# 4/4 [==============================] - 0s 120ms/step - loss: 1.0183e-04 - val_loss: 1.0609e-04
# Epoch 79/100
# 4/4 [==============================] - 1s 164ms/step - loss: 1.1018e-04 - val_loss: 1.0335e-04
# Epoch 80/100
# 4/4 [==============================] - 1s 136ms/step - loss: 1.0203e-04 - val_loss: 1.0479e-04
# Epoch 81/100
# 4/4 [==============================] - 1s 148ms/step - loss: 1.0301e-04 - val_loss: 1.0310e-04
# Epoch 82/100
# 4/4 [==============================] - 1s 232ms/step - loss: 1.0329e-04 - val_loss: 1.0239e-04
# Epoch 83/100
# 4/4 [==============================] - 1s 169ms/step - loss: 1.0630e-04 - val_loss: 1.0256e-04
# Epoch 84/100
# 4/4 [==============================] - 1s 200ms/step - loss: 1.0491e-04 - val_loss: 1.0138e-04
# Epoch 85/100
# 4/4 [==============================] - 1s 159ms/step - loss: 1.0518e-04 - val_loss: 1.0218e-04
# Epoch 86/100
# 4/4 [==============================] - 1s 125ms/step - loss: 1.0252e-04 - val_loss: 1.0072e-04
# Epoch 87/100
# 4/4 [==============================] - 1s 134ms/step - loss: 1.0234e-04 - val_loss: 1.0182e-04
# Epoch 88/100
# 4/4 [==============================] - 0s 121ms/step - loss: 1.0500e-04 - val_loss: 1.0029e-04
# Epoch 89/100
# 4/4 [==============================] - 0s 118ms/step - loss: 9.9154e-05 - val_loss: 9.9938e-05
# Epoch 90/100
# 4/4 [==============================] - 0s 121ms/step - loss: 1.0174e-04 - val_loss: 1.0007e-04
# Epoch 91/100
# 4/4 [==============================] - 0s 121ms/step - loss: 1.0073e-04 - val_loss: 9.8880e-05
# Epoch 92/100
# 4/4 [==============================] - 0s 119ms/step - loss: 1.0063e-04 - val_loss: 9.8788e-05
# Epoch 93/100
# 4/4 [==============================] - 0s 116ms/step - loss: 1.0149e-04 - val_loss: 9.8468e-05
# Epoch 94/100
# 4/4 [==============================] - 0s 120ms/step - loss: 9.8540e-05 - val_loss: 9.8608e-05
# Epoch 95/100
# 4/4 [==============================] - 0s 123ms/step - loss: 9.8762e-05 - val_loss: 9.8184e-05
# Epoch 96/100
# 4/4 [==============================] - 1s 178ms/step - loss: 9.9932e-05 - val_loss: 9.7428e-05
# Epoch 97/100
# 4/4 [==============================] - 0s 122ms/step - loss: 9.3646e-05 - val_loss: 9.7266e-05
# Epoch 98/100
# 4/4 [==============================] - 0s 121ms/step - loss: 9.7752e-05 - val_loss: 9.6890e-05
# Epoch 99/100
# 4/4 [==============================] - 0s 122ms/step - loss: 9.5920e-05 - val_loss: 9.7157e-05
# Epoch 100/100
# 4/4 [==============================] - 0s 119ms/step - loss: 9.0280e-05 - val_loss: 9.5904e-05

# %% [markdown]
# ##### 결과 시각화

# %%
plt.plot(hist.epoch, hist.history['loss'])
plt.plot(hist.epoch, hist.history['val_loss']);
plt.ylim(0,0.001)
plt.show()

# %% [markdown]
# ##### 최종평가

# %%
model.evaluate(test_dataset)
# Out:
# 2/2 [==============================] - 0s 17ms/step - loss: 9.5904e-05
# 9.590363333700225e-05

# %% [markdown]
# ##### 다음날 주가 예측
# - 마지막 50일치로 내일 주가를 예측해 본다.

# %%
X[-50:][np.newaxis, ...].shape
# Out:
# (1, 50, 5)

# %%
new_data = X[-50:][np.newaxis, ...]
new_data.shape
# Out:
# (1, 50, 5)

# %%
pred = model.predict(new_data)
# Out:
# 1/1 [==============================] - 0s 426ms/step

# %%
pred
# Out:
# array([[0.6650553]], dtype=float32)

# %%
y_scaler.inverse_transform(pred)
# Out:
# array([[61434.43]], dtype=float32)
